# %% [markdown]
# # Benchmarking V7 reduced datset with AutoGluon
# # Using presets

# %%
# !nvidia-smi
# Out:
# Sun Apr 16 22:32:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    46W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !lsb_release -a

# %% [markdown]
# # Connecting to google drive and directing to folders with valtrain and test sets

# %%
from google.colab import drive
drive.mount('/content/MyDrive')
# Out:
# Drive already mounted at /content/MyDrive; to attempt to forcibly remount, call drive.mount("/content/MyDrive", force_remount=True).

# %% [markdown]
# # Iinstalling CUDA

# %%
# !pip install --upgrade mxnet-cu112
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mxnet-cu112 in /usr/local/lib/python3.9/dist-packages (1.9.1)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.9/dist-packages (from mxnet-cu112) (1.22.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.9/dist-packages (from mxnet-cu112) (2.27.1)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from mxnet-cu112) (0.8.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet-cu112) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet-cu112) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet-cu112) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet-cu112) (1.26.15)

# %% [markdown]
# Approximately 3 minutes to install

# %%
# !pip install autogluon==0.6.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: autogluon==0.6.2 in /usr/local/lib/python3.9/dist-packages (0.6.2)
# Requirement already satisfied: autogluon.features==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: autogluon.tabular[all]==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: autogluon.timeseries[all]==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: autogluon.vision==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: autogluon.core[all]==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: autogluon.text==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: autogluon.multimodal==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.26.114)
# Requirement already satisfied: scipy<1.10.0,>=1.5.4 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.8.1)
# Requirement already satisfied: scikit-learn<1.2,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.1.3)
# Requirement already satisfied: distributed<=2021.11.2,>=2021.09.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (2021.11.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.7.1)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.8.8)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (4.65.0)
# Requirement already satisfied: autogluon.common==0.6.2 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.6.2)
# Requirement already satisfied: psutil<6,>=5.7.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (5.9.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.27.1)
# Requirement already satisfied: dask<=2021.11.2,>=2021.09.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (2021.11.2)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>=1.2.5 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.5.3)
# Requirement already satisfied: numpy<1.24,>=1.21 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.22.4)
# Requirement already satisfied: ray[tune]<2.1,>=2.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.0.1)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.2.7)
# Requirement already satisfied: nlpaug<=1.1.10,>=1.1.10 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.1.10)
# Requirement already satisfied: scikit-image<0.20.0,>=0.19.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.19.3)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (3.8.1)
# Requirement already satisfied: nptyping<1.5.0,>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.4.4)
# Requirement already satisfied: Pillow<=9.4.0,>=9.3.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (9.4.0)
# Requirement already satisfied: sentencepiece<0.2.0,>=0.1.95 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.1.98)
# Requirement already satisfied: pytorch-metric-learning<1.4.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.3.2)
# Requirement already satisfied: albumentations<=1.2.0,>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.1.0)
# Requirement already satisfied: pytorch-lightning<1.8.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.7.7)
# Requirement already satisfied: torchvision<0.14.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.13.1)
# Requirement already satisfied: defusedxml<=0.7.1,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.7.1)
# Requirement already satisfied: openmim<=0.2.1,>0.1.5 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.2.1)
# Requirement already satisfied: torch<1.13,>=1.9 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.12.1)
# Requirement already satisfied: omegaconf<2.2.0,>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.1.2)
# Requirement already satisfied: fairscale<=0.4.6,>=0.4.5 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.4.6)
# Requirement already satisfied: text-unidecode<=1.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.3)
# Requirement already satisfied: seqeval<=1.2.2 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.2.2)
# Requirement already satisfied: transformers<4.24.0,>=4.23.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (4.23.1)
# Requirement already satisfied: accelerate<0.14,>=0.9 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.13.2)
# Requirement already satisfied: torchmetrics<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.8.2)
# Requirement already satisfied: jsonschema<=4.8.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (4.3.3)
# Requirement already satisfied: evaluate<=0.3.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.3.0)
# Requirement already satisfied: smart-open<5.3.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (5.2.1)
# Requirement already satisfied: timm<0.7.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.6.13)
# Requirement already satisfied: torchtext<0.14.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.13.1)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (2.7.12)
# Requirement already satisfied: catboost<1.2,>=1.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.1.1)
# Requirement already satisfied: lightgbm<3.4,>=3.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (3.3.5)
# Requirement already satisfied: xgboost<1.8,>=1.6 in /usr/local/lib/python3.9/dist-packages (from autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.7.5)
# Requirement already satisfied: gluonts~=0.11.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (0.11.12)
# Requirement already satisfied: joblib~=1.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (1.2.0)
# Requirement already satisfied: statsmodels~=0.13.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (0.13.5)
# Requirement already satisfied: tbats~=1.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (1.1.2)
# Requirement already satisfied: pmdarima~=1.8.2 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (1.8.5)
# Requirement already satisfied: sktime<0.14,>=0.13.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (0.13.4)
# Requirement already satisfied: gluoncv<0.10.6,>=0.10.5 in /usr/local/lib/python3.9/dist-packages (from autogluon.vision==0.6.2->autogluon==0.6.2) (0.10.5.post0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from autogluon.common==0.6.2->autogluon.core[all]==0.6.2->autogluon==0.6.2) (67.6.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from accelerate<0.14,>=0.9->autogluon.multimodal==0.6.2->autogluon==0.6.2) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from accelerate<0.14,>=0.9->autogluon.multimodal==0.6.2->autogluon==0.6.2) (23.0)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from albumentations<=1.2.0,>=1.1.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (4.7.0.72)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from albumentations<=1.2.0,>=1.1.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.0.4)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (0.8.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.16.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.9/dist-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2023.4.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (6.2)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.0.5)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.2.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.9/dist-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.1.2)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.9/dist-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (8.0.4)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.13.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.18.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.9/dist-packages (from evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.3.6)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.11.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.70.14)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (3.5.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.5.29)
# Requirement already satisfied: pip in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (23.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.0.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.2->autogluon==0.6.2) (4.7.0.72)
# Requirement already satisfied: autocfg in /usr/local/lib/python3.9/dist-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.2->autogluon==0.6.2) (0.0.8)
# Requirement already satisfied: yacs in /usr/local/lib/python3.9/dist-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.2->autogluon==0.6.2) (0.1.8)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.9/dist-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.2->autogluon==0.6.2) (2.7.0)
# Requirement already satisfied: pydantic~=1.7 in /usr/local/lib/python3.9/dist-packages (from gluonts~=0.11.0->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (1.10.7)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.9/dist-packages (from gluonts~=0.11.0->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (4.5.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.9/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.10.9.7)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.18.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema<=4.8.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema<=4.8.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.19.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm<3.4,>=3.3->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (0.40.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2022.10.31)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from nptyping<1.5.0,>=1.4.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.9.3)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.9/dist-packages (from omegaconf<2.2.0,>=2.1.1->autogluon.multimodal==0.6.2->autogluon==0.6.2) (4.8)
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.4.6)
# Requirement already satisfied: model-index in /usr/local/lib/python3.9/dist-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.1.11)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.8.10)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (13.3.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas!=1.4.0,<1.6,>=1.2.5->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas!=1.4.0,<1.6,>=1.2.5->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.8.2)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima~=1.8.2->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (0.29.34)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima~=1.8.2->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (1.26.15)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.11.2)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.3.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.9/dist-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.3.1)
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.9/dist-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (20.21.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.9/dist-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.3.3)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.9/dist-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.11.0)
# Requirement already satisfied: grpcio<=1.43.0,>=1.32.0 in /usr/local/lib/python3.9/dist-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.43.0)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.9/dist-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.0.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2023.3.21)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.25.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<1.2,>=1.0.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.1.0)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.9/dist-packages (from sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (1.2.13)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.9/dist-packages (from sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (0.56.4)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels~=0.13.0->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (0.5.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<4.24.0,>=4.23.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.13.3)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3->autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.0.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.114 in /usr/local/lib/python3.9/dist-packages (from boto3->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.29.114)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.6.2->autogluon==0.6.2) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.6.2->autogluon==0.6.2) (4.39.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (3.8.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (1.14.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.15.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.53->sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.2->autogluon==0.6.2) (0.39.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.9/dist-packages (from partd>=0.3.10->dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.0.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (2.4.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.0.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (2.0.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.1.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (3.0.12)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (8.1.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (1.0.9)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (3.4.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.17.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.8.1)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.9/dist-packages (from zict>=0.1.3->distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.2->autogluon==0.6.2) (2.1.2)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.9/dist-packages (from model-index->openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (4.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (8.2.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (2.2.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.9/dist-packages (from virtualenv->ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (3.2.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.9/dist-packages (from virtualenv->ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.2->autogluon==0.6.2) (0.3.6)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<=0.3.0->autogluon.multimodal==0.6.2->autogluon==0.6.2) (6.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (6.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.1.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.2->autogluon==0.6.2) (0.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.2->autogluon==0.6.2) (3.2.2)

# %% [markdown]
# Restart runtime after installing ipykernel (~13 seconds)

# %%
# !pip install -U ipykernel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (5.5.6)
# Collecting ipykernel
#   Downloading ipykernel-6.22.0-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from ipykernel) (23.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (7.34.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (from ipykernel) (1.5.6)
# Collecting comm>=0.1.1
#   Downloading comm-0.1.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (1.6.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from ipykernel) (5.9.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (6.1.12)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.9/dist-packages (from ipykernel) (23.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.1 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=7.23.1->ipykernel) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=7.23.1->ipykernel) (2.14.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=7.23.1->ipykernel) (67.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/dist-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Installing collected packages: jedi, comm, ipykernel
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel~=5.5.6, but you have ipykernel 6.22.0 which is incompatible.
# Successfully installed comm-0.1.3 ipykernel-6.22.0 jedi-0.18.2

# %%
import autogluon as ag

# %%
from autogluon.vision import ObjectDetector
# Out:
# /usr/local/lib/python3.9/dist-packages/gluoncv/__init__.py:16: UserWarning: Both `mxnet==1.9.1` and `torch==1.12.1+cu102` are installed. You might encounter increased GPU memory footprint if both framework are used at the same time.
#   _require_mxnet_version('1.4.0', '2.0.0')
# 2023-04-17 03:59:44.508472: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-17 03:59:44.568826: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 03:59:45.562842: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Changing into directory where datasets are stored

# %%
#! original
# %cd /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced

#! modified
# %cd /content/drive/MyDrive/Colab_Notebooks/benchmark_project/V7_reduced
# Out:
# /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced

# %%
# !ls
# Out:
# V7_test  V7_train  V7_validation

# %%
#!sudo apt install tree
#!tree -d

# %%
import os

images_count = 0
annotation_count = 0

images_dir = os.getcwd()+"/V7_train/V7/JPEGImages/"
annotation_dir = os.getcwd()+"/V7_train/V7/Annotations/"

for path in os.listdir(images_dir):
  if os.path.isfile(os.path.join(images_dir,path)):
    images_count+=1

for path in os.listdir(annotation_dir):
  if os.path.isfile(os.path.join(annotation_dir,path)):
    annotation_count+=1

print("Images count:", images_count)
print("Annotation count:", annotation_count)
# Out:
# Images count: 5040
# Annotation count: 5040

# %% [markdown]
# ### Trying to check the "trainval.txt" file and see if it has corresponding annotations (.xml) and images (.jpg) for each line listed.

# %%
def check_if_existsJPG(file_path, string):
    # check if the file exists in the given folder path
    return os.path.exists(os.path.join(file_path, string + ".jpg"))

def check_if_existsXML(file_path, string):
  return os.path.exists(os.path.join(file_path, string + ".xml"))

def read_strings_from_file(file_name):
    # read strings from a file, where each string is separated by a new line
    with open(file_name, "r") as file:
        strings = file.read().splitlines()
    return strings

def jpgCheck(strings_file, folder_path):
    # read strings from the given file
    strings = read_strings_from_file(strings_file)
    exists = 0
    nonexists = 0

    # check if the corresponding file with .jpg extension exists in the folder
    for string in strings:
        if check_if_existsJPG(folder_path, string):
            #print(f"{string}.jpg exists in {folder_path}")
            exists = exists + 1 
        else:
            #print(f"{string}.jpg does not exist in {folder_path}")
            nonexists = nonexists + 1

    return exists, nonexists

def xmlCheck(strings_file, folder_path):
    # read strings from the given file
    strings = read_strings_from_file(strings_file)
    exists = 0
    nonexists = 0

    # check if the corresponding file with .jpg extension exists in the folder
    for string in strings:
        if check_if_existsXML(folder_path, string):
            #print(f"{string}.jpg exists in {folder_path}")
            exists = exists + 1 
        else:
            #print(f"{string}.xml does not exist in {folder_path}")
            nonexists = nonexists + 1

    return exists, nonexists

# %%
numExist = jpgCheck(os.getcwd()+'/V7_validation/V7/ImageSets/Main/validation.txt', os.getcwd()+'/V7_validation/V7/JPEGImages')
print(numExist)
# Out:
# (1080, 0)

# %%
xmlExist = xmlCheck(os.getcwd()+'/V7_validation/V7/ImageSets/Main/validation.txt', os.getcwd()+'/V7_validation/V7/Annotations')
print(xmlExist)
# Out:
# (1080, 0)

# %% [markdown]
# ### Main chunk of code for training. Below we are importing the dataset and running it. Will take some time.

# %%
dataset_train = ObjectDetector.Dataset.from_voc(root='V7_train/V7', splits='train')
dataset_val = ObjectDetector.Dataset.from_voc(root='V7_validation/V7', splits='validation')

detector = ObjectDetector()

import traceback
try:
    detector.fit(train_data=dataset_train, tuning_data=dataset_val, presets='good_quality_fast_inference', ngpus_per_trial=1)
except Exception as e:
    traceback.print_exc()

#Saving model
#! original
# savefile = '/content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/V7_detector.ag'

#! modified
savefile = '/content/drive/MyDrive/Colab_Notebooks/benchmark_project/V7_reduced/V7_detector.ag'
detector.save(savefile)
# Out:
# =============================================================================
# WARNING: ObjectDetector is deprecated as of v0.4.0 and may contain various bugs and issues!
# In a future release ObjectDetector may be entirely reworked to use Torch as a backend.
# This future change will likely be API breaking.Users should ensure they update their code that depends on ObjectDetector when upgrading to future AutoGluon releases.
# For more information, refer to ObjectDetector refactor GitHub issue: https://github.com/autogluon/autogluon/issues/1559
# =============================================================================
#
# Presets specified: ['good_quality_fast_inference']
# Starting HPO experiments
#   0%|          | 0/512 [00:00<?, ?it/s]
# INFO:SSDEstimator:modified configs(<old> != <new>): {
# INFO:SSDEstimator:root.valid.batch_size 16 != 8
# INFO:SSDEstimator:root.dataset         voc_tiny != auto
# INFO:SSDEstimator:root.dataset_root    ~/.mxnet/datasets/ != auto
# INFO:SSDEstimator:root.train.epochs    20 != 50
# INFO:SSDEstimator:root.train.seed      233 != 46
# INFO:SSDEstimator:root.train.lr        0.001 != 0.0001
# INFO:SSDEstimator:root.train.early_stop_max_value 1.0 != inf
# INFO:SSDEstimator:root.train.early_stop_patience -1 != 20
# INFO:SSDEstimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:SSDEstimator:root.train.batch_size 16 != 8
# INFO:SSDEstimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:SSDEstimator:root.num_workers     4 != 12
# INFO:SSDEstimator:root.ssd.data_shape  300 != 512
# INFO:SSDEstimator:root.ssd.base_network vgg16_atrous != resnet50_v1
# INFO:SSDEstimator:}
# INFO:SSDEstimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/config.yaml
# [01:06:24] ../src/base.cc:79: cuDNN lib mismatch: linked-against version 8700 != compiled-against version 8101.  Set MXNET_CUDNN_LIB_CHECKING=0 to quiet this warning.
# INFO:SSDEstimator:Using transfer learning from ssd_512_resnet50_v1_coco, the other network parameters are ignored.
# Downloading /root/.mxnet/models/ssd_512_resnet50_v1_coco-c4835162.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/ssd_512_resnet50_v1_coco-c4835162.zip...
#   0%|          | 0/181188 [00:00<?, ?KB/s]
#   0%|          | 25/181188 [00:00<18:47, 160.67KB/s]
#   0%|          | 92/181188 [00:00<09:35, 314.89KB/s]
#   0%|          | 234/181188 [00:00<05:12, 579.71KB/s]
#   0%|          | 506/181188 [00:00<02:56, 1026.30KB/s]
#   1%|          | 1077/181188 [00:00<01:32, 1950.08KB/s]
#   1%|          | 2181/181188 [00:00<00:49, 3645.73KB/s]
#   2%|▏         | 4405/181188 [00:01<00:25, 7021.16KB/s]
#   5%|▍         | 8709/181188 [00:01<00:12, 13373.70KB/s]
#   7%|▋         | 12613/181188 [00:01<00:09, 16872.32KB/s]
#   9%|▉         | 16869/181188 [00:01<00:08, 19906.52KB/s]
#  12%|█▏        | 21269/181188 [00:01<00:07, 22265.45KB/s]
#  14%|█▍        | 25397/181188 [00:01<00:06, 23354.85KB/s]
#  16%|█▋        | 29829/181188 [00:02<00:06, 24714.16KB/s]
#  19%|█▊        | 33845/181188 [00:02<00:05, 24842.38KB/s]
#  21%|██        | 38437/181188 [00:02<00:05, 26040.14KB/s]
#  24%|██▎       | 42677/181188 [00:02<00:05, 26219.98KB/s]
#  26%|██▋       | 47685/181188 [00:02<00:04, 27775.92KB/s]
#  29%|██▉       | 52469/181188 [00:02<00:04, 28459.75KB/s]
#  31%|███▏      | 56677/181188 [00:03<00:04, 27826.81KB/s]
#  34%|███▍      | 61717/181188 [00:03<00:04, 28986.58KB/s]
#  36%|███▋      | 66085/181188 [00:03<00:04, 28482.18KB/s]
#  39%|███▉      | 71157/181188 [00:03<00:03, 29517.78KB/s]
#  42%|████▏     | 76149/181188 [00:03<00:03, 30058.12KB/s]
#  45%|████▍     | 81189/181188 [00:03<00:03, 30528.87KB/s]
#  48%|████▊     | 86277/181188 [00:03<00:03, 30958.69KB/s]
#  50%|█████     | 91333/181188 [00:04<00:02, 31180.39KB/s]
#  53%|█████▎    | 96405/181188 [00:04<00:02, 31390.61KB/s]
#  56%|█████▌    | 101413/181188 [00:04<00:02, 31399.75KB/s]
#  59%|█████▊    | 106437/181188 [00:04<00:02, 31429.97KB/s]
#  62%|██████▏   | 111525/181188 [00:04<00:02, 31578.66KB/s]
#  64%|██████▍   | 115957/181188 [00:04<00:02, 30462.43KB/s]
#  67%|██████▋   | 120981/181188 [00:05<00:01, 30779.92KB/s]
#  70%|██████▉   | 126037/181188 [00:05<00:01, 31074.75KB/s]
#  72%|███████▏  | 131061/181188 [00:05<00:01, 31206.75KB/s]
#  75%|███████▌  | 136149/181188 [00:05<00:01, 31427.52KB/s]
#  78%|███████▊  | 141253/181188 [00:05<00:01, 31612.46KB/s]
#  81%|████████  | 146357/181188 [00:05<00:01, 31742.12KB/s]
#  84%|████████▎ | 151429/181188 [00:06<00:00, 31712.28KB/s]
#  86%|████████▋ | 156485/181188 [00:06<00:00, 31768.01KB/s]
#  89%|████████▉ | 161301/181188 [00:06<00:00, 31279.18KB/s]
#  92%|█████████▏| 166325/181188 [00:06<00:00, 31379.74KB/s]
#  95%|█████████▍| 171381/181188 [00:06<00:00, 31488.33KB/s]
#  97%|█████████▋| 175205/181188 [00:06<00:00, 29227.54KB/s]
# 181189KB [00:07, 25801.84KB/s]
# INFO:SSDEstimator:Start training from [Epoch 0]
# [01:06:54] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# INFO:SSDEstimator:[Epoch 0][Batch 99], Speed: 0.129780 samples/sec, CrossEntropy=1.917132, SmoothL1=0.492101
# INFO:SSDEstimator:[Epoch 0][Batch 199], Speed: 0.146300 samples/sec, CrossEntropy=1.900106, SmoothL1=0.525190
# INFO:SSDEstimator:[Epoch 0][Batch 299], Speed: 0.143877 samples/sec, CrossEntropy=1.916062, SmoothL1=0.521354
# INFO:SSDEstimator:[Epoch 0][Batch 399], Speed: 0.137275 samples/sec, CrossEntropy=1.916942, SmoothL1=0.508321
# INFO:SSDEstimator:[Epoch 0][Batch 499], Speed: 0.132204 samples/sec, CrossEntropy=1.921038, SmoothL1=0.519628
# INFO:SSDEstimator:[Epoch 0][Batch 599], Speed: 0.149254 samples/sec, CrossEntropy=1.931764, SmoothL1=0.517215
# INFO:SSDEstimator:[Epoch 0] Training cost: 361.232812, CrossEntropy=1.922154, SmoothL1=0.515721
# INFO:SSDEstimator:[Epoch 0] Validation:
# person=0.5382687943426298
# bus=0.9814722559627431
# bird=0.8162620097753797
# horse=0.8812712145400486
# dog=0.8619543704498316
# airplane=0.9040959040959042
# train=0.8703609937340516
# cat=0.8909111944902356
# boat=0.828986816029499
# mAP=0.8415092837133692
# INFO:SSDEstimator:[Epoch 0] Current best map: 0.841509 vs previous 0.000000, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 1][Batch 99], Speed: 0.536258 samples/sec, CrossEntropy=1.865940, SmoothL1=0.524428
# INFO:SSDEstimator:[Epoch 1][Batch 199], Speed: 0.677977 samples/sec, CrossEntropy=1.782964, SmoothL1=0.473739
# INFO:SSDEstimator:[Epoch 1][Batch 299], Speed: 0.677755 samples/sec, CrossEntropy=1.802265, SmoothL1=0.489694
# INFO:SSDEstimator:[Epoch 1][Batch 399], Speed: 0.667161 samples/sec, CrossEntropy=1.798102, SmoothL1=0.483380
# INFO:SSDEstimator:[Epoch 1][Batch 499], Speed: 0.678677 samples/sec, CrossEntropy=1.797764, SmoothL1=0.480355
# INFO:SSDEstimator:[Epoch 1][Batch 599], Speed: 0.649321 samples/sec, CrossEntropy=1.792246, SmoothL1=0.482843
# INFO:SSDEstimator:[Epoch 1] Training cost: 77.384395, CrossEntropy=1.785266, SmoothL1=0.481328
# INFO:SSDEstimator:[Epoch 1] Validation:
# person=0.5904203454209168
# bus=0.9848929500433536
# bird=0.8068268909550186
# horse=0.8830148858774814
# dog=0.8140988436850506
# airplane=0.8964298178542399
# train=0.8874117564122088
# cat=0.8725664806960247
# boat=0.8009605637519305
# mAP=0.837402503855136
# INFO:SSDEstimator:[Epoch 2][Batch 99], Speed: 0.533460 samples/sec, CrossEntropy=1.555176, SmoothL1=0.384509
# INFO:SSDEstimator:[Epoch 2][Batch 199], Speed: 0.672990 samples/sec, CrossEntropy=1.591058, SmoothL1=0.416689
# INFO:SSDEstimator:[Epoch 2][Batch 299], Speed: 0.669868 samples/sec, CrossEntropy=1.608770, SmoothL1=0.429176
# INFO:SSDEstimator:[Epoch 2][Batch 399], Speed: 0.657198 samples/sec, CrossEntropy=1.638035, SmoothL1=0.438180
# INFO:SSDEstimator:[Epoch 2][Batch 499], Speed: 0.659710 samples/sec, CrossEntropy=1.662548, SmoothL1=0.449511
# INFO:SSDEstimator:[Epoch 2][Batch 599], Speed: 0.686583 samples/sec, CrossEntropy=1.682720, SmoothL1=0.450659
# INFO:SSDEstimator:[Epoch 2] Training cost: 77.682142, CrossEntropy=1.690818, SmoothL1=0.451098
# INFO:SSDEstimator:[Epoch 2] Validation:
# person=0.5963629199599924
# bus=0.9857316801289637
# bird=0.8192403369160232
# horse=0.9232624632076128
# dog=0.876211408584795
# airplane=0.8831151201060841
# train=0.8350900805586987
# cat=0.9119452123935768
# boat=0.8199782998959998
# mAP=0.8501041690835273
# INFO:SSDEstimator:[Epoch 2] Current best map: 0.850104 vs previous 0.841509, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 3][Batch 99], Speed: 0.537227 samples/sec, CrossEntropy=1.523973, SmoothL1=0.408009
# INFO:SSDEstimator:[Epoch 3][Batch 199], Speed: 0.659481 samples/sec, CrossEntropy=1.545997, SmoothL1=0.415083
# INFO:SSDEstimator:[Epoch 3][Batch 299], Speed: 0.657271 samples/sec, CrossEntropy=1.587367, SmoothL1=0.426668
# INFO:SSDEstimator:[Epoch 3][Batch 399], Speed: 0.647132 samples/sec, CrossEntropy=1.597996, SmoothL1=0.414489
# INFO:SSDEstimator:[Epoch 3][Batch 499], Speed: 0.629584 samples/sec, CrossEntropy=1.585326, SmoothL1=0.414008
# INFO:SSDEstimator:[Epoch 3][Batch 599], Speed: 0.639721 samples/sec, CrossEntropy=1.603226, SmoothL1=0.420022
# INFO:SSDEstimator:[Epoch 3] Training cost: 79.758021, CrossEntropy=1.609352, SmoothL1=0.422868
# INFO:SSDEstimator:[Epoch 3] Validation:
# person=0.5384769820025329
# bus=0.9672399672399674
# bird=0.8250134753338059
# horse=0.8946840659534846
# dog=0.8385537542033725
# airplane=0.8982254210248041
# train=0.8504977776797398
# cat=0.9259622769110855
# boat=0.7779682842666201
# mAP=0.835180222735046
# INFO:SSDEstimator:[Epoch 4][Batch 99], Speed: 0.557150 samples/sec, CrossEntropy=1.625854, SmoothL1=0.411881
# INFO:SSDEstimator:[Epoch 4][Batch 199], Speed: 0.631086 samples/sec, CrossEntropy=1.557096, SmoothL1=0.385440
# INFO:SSDEstimator:[Epoch 4][Batch 299], Speed: 0.674198 samples/sec, CrossEntropy=1.564033, SmoothL1=0.407484
# INFO:SSDEstimator:[Epoch 4][Batch 399], Speed: 0.644540 samples/sec, CrossEntropy=1.560528, SmoothL1=0.405594
# INFO:SSDEstimator:[Epoch 4][Batch 499], Speed: 0.652105 samples/sec, CrossEntropy=1.571595, SmoothL1=0.410747
# INFO:SSDEstimator:[Epoch 4][Batch 599], Speed: 0.639307 samples/sec, CrossEntropy=1.575499, SmoothL1=0.419271
# INFO:SSDEstimator:[Epoch 4] Training cost: 79.011035, CrossEntropy=1.580150, SmoothL1=0.421610
# INFO:SSDEstimator:[Epoch 4] Validation:
# person=0.5560142338818197
# bus=0.9785302416881366
# bird=0.8314002696298002
# horse=0.9086644015761883
# dog=0.8491328737832651
# airplane=0.9047969816744521
# train=0.8809233123186613
# cat=0.8990215384581935
# boat=0.8113090238789766
# mAP=0.8466436529877215
# INFO:SSDEstimator:[Epoch 5][Batch 99], Speed: 0.565947 samples/sec, CrossEntropy=1.574369, SmoothL1=0.390736
# INFO:SSDEstimator:[Epoch 5][Batch 199], Speed: 0.655563 samples/sec, CrossEntropy=1.569794, SmoothL1=0.414286
# INFO:SSDEstimator:[Epoch 5][Batch 299], Speed: 0.651078 samples/sec, CrossEntropy=1.573977, SmoothL1=0.410367
# INFO:SSDEstimator:[Epoch 5][Batch 399], Speed: 0.654161 samples/sec, CrossEntropy=1.546935, SmoothL1=0.413788
# INFO:SSDEstimator:[Epoch 5][Batch 499], Speed: 0.673872 samples/sec, CrossEntropy=1.534054, SmoothL1=0.409077
# INFO:SSDEstimator:[Epoch 5][Batch 599], Speed: 0.618275 samples/sec, CrossEntropy=1.532742, SmoothL1=0.407253
# INFO:SSDEstimator:[Epoch 5] Training cost: 78.488026, CrossEntropy=1.544019, SmoothL1=0.408467
# INFO:SSDEstimator:[Epoch 5] Validation:
# person=0.601374391841197
# bus=0.9739951920165111
# bird=0.8536169551359539
# horse=0.8965184824785056
# dog=0.8619011604376137
# airplane=0.9088116507849787
# train=0.8978080619590055
# cat=0.891014872623385
# boat=0.8089575953627525
# mAP=0.8548887069599892
# INFO:SSDEstimator:[Epoch 5] Current best map: 0.854889 vs previous 0.850104, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 6][Batch 99], Speed: 0.509783 samples/sec, CrossEntropy=1.454971, SmoothL1=0.370628
# INFO:SSDEstimator:[Epoch 6][Batch 199], Speed: 0.640778 samples/sec, CrossEntropy=1.484871, SmoothL1=0.391333
# INFO:SSDEstimator:[Epoch 6][Batch 299], Speed: 0.615334 samples/sec, CrossEntropy=1.495922, SmoothL1=0.397190
# INFO:SSDEstimator:[Epoch 6][Batch 399], Speed: 0.657630 samples/sec, CrossEntropy=1.491385, SmoothL1=0.396601
# INFO:SSDEstimator:[Epoch 6][Batch 499], Speed: 0.631069 samples/sec, CrossEntropy=1.484005, SmoothL1=0.398546
# INFO:SSDEstimator:[Epoch 6][Batch 599], Speed: 0.662271 samples/sec, CrossEntropy=1.491170, SmoothL1=0.402919
# INFO:SSDEstimator:[Epoch 6] Training cost: 80.936747, CrossEntropy=1.491010, SmoothL1=0.402940
# INFO:SSDEstimator:[Epoch 6] Validation:
# person=0.6217153622035029
# bus=0.9902801206519218
# bird=0.8522654301814305
# horse=0.8811761909587996
# dog=0.8577375354833976
# airplane=0.8908082209053084
# train=0.8790569359718297
# cat=0.889456107069211
# boat=0.7959201671288118
# mAP=0.8509351189504681
# INFO:SSDEstimator:[Epoch 7][Batch 99], Speed: 0.558131 samples/sec, CrossEntropy=1.467975, SmoothL1=0.371025
# INFO:SSDEstimator:[Epoch 7][Batch 199], Speed: 0.632622 samples/sec, CrossEntropy=1.454238, SmoothL1=0.382556
# INFO:SSDEstimator:[Epoch 7][Batch 299], Speed: 0.642178 samples/sec, CrossEntropy=1.474312, SmoothL1=0.395608
# INFO:SSDEstimator:[Epoch 7][Batch 399], Speed: 0.649312 samples/sec, CrossEntropy=1.455095, SmoothL1=0.386990
# INFO:SSDEstimator:[Epoch 7][Batch 499], Speed: 0.647673 samples/sec, CrossEntropy=1.478327, SmoothL1=0.392734
# INFO:SSDEstimator:[Epoch 7][Batch 599], Speed: 0.658680 samples/sec, CrossEntropy=1.479034, SmoothL1=0.398340
# INFO:SSDEstimator:[Epoch 7] Training cost: 79.148682, CrossEntropy=1.480778, SmoothL1=0.400582
# INFO:SSDEstimator:[Epoch 7] Validation:
# person=0.588040907820678
# bus=0.9880073918744204
# bird=0.8535485274849892
# horse=0.8864485854407027
# dog=0.8683220404181686
# airplane=0.8907421208767445
# train=0.8785176103149311
# cat=0.9166919829130838
# boat=0.8147244488944502
# mAP=0.853893735115352
# INFO:SSDEstimator:[Epoch 8][Batch 99], Speed: 0.573303 samples/sec, CrossEntropy=1.377847, SmoothL1=0.359993
# INFO:SSDEstimator:[Epoch 8][Batch 199], Speed: 0.646769 samples/sec, CrossEntropy=1.426411, SmoothL1=0.378951
# INFO:SSDEstimator:[Epoch 8][Batch 299], Speed: 0.665770 samples/sec, CrossEntropy=1.447438, SmoothL1=0.381540
# INFO:SSDEstimator:[Epoch 8][Batch 399], Speed: 0.638098 samples/sec, CrossEntropy=1.471337, SmoothL1=0.389001
# INFO:SSDEstimator:[Epoch 8][Batch 499], Speed: 0.658547 samples/sec, CrossEntropy=1.447962, SmoothL1=0.375179
# INFO:SSDEstimator:[Epoch 8][Batch 599], Speed: 0.622287 samples/sec, CrossEntropy=1.447431, SmoothL1=0.376550
# INFO:SSDEstimator:[Epoch 8] Training cost: 78.721045, CrossEntropy=1.445659, SmoothL1=0.377144
# INFO:SSDEstimator:[Epoch 8] Validation:
# person=0.6294976708234692
# bus=0.9898989898989901
# bird=0.8579121413346014
# horse=0.8833392115131247
# dog=0.86616709657462
# airplane=0.9047786190643334
# train=0.8841649676488387
# cat=0.8980391529652612
# boat=0.8224340961254861
# mAP=0.859581327327636
# INFO:SSDEstimator:[Epoch 8] Current best map: 0.859581 vs previous 0.854889, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 9][Batch 99], Speed: 0.508984 samples/sec, CrossEntropy=1.293755, SmoothL1=0.345599
# INFO:SSDEstimator:[Epoch 9][Batch 199], Speed: 0.669437 samples/sec, CrossEntropy=1.340623, SmoothL1=0.371265
# INFO:SSDEstimator:[Epoch 9][Batch 299], Speed: 0.636326 samples/sec, CrossEntropy=1.354682, SmoothL1=0.373499
# INFO:SSDEstimator:[Epoch 9][Batch 399], Speed: 0.641769 samples/sec, CrossEntropy=1.366360, SmoothL1=0.374017
# INFO:SSDEstimator:[Epoch 9][Batch 499], Speed: 0.660213 samples/sec, CrossEntropy=1.373458, SmoothL1=0.370948
# INFO:SSDEstimator:[Epoch 9][Batch 599], Speed: 0.637569 samples/sec, CrossEntropy=1.383875, SmoothL1=0.373655
# INFO:SSDEstimator:[Epoch 9] Training cost: 80.107590, CrossEntropy=1.382417, SmoothL1=0.373433
# INFO:SSDEstimator:[Epoch 9] Validation:
# person=0.652637562455769
# bus=0.9970674486803521
# bird=0.8602595446060602
# horse=0.8973152934022501
# dog=0.8647663814175673
# airplane=0.8962678940044155
# train=0.9037093464340085
# cat=0.9176881314323485
# boat=0.8327286883607283
# mAP=0.8691600323103889
# INFO:SSDEstimator:[Epoch 9] Current best map: 0.869160 vs previous 0.859581, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 10][Batch 99], Speed: 0.540365 samples/sec, CrossEntropy=1.378423, SmoothL1=0.349474
# INFO:SSDEstimator:[Epoch 10][Batch 199], Speed: 0.622768 samples/sec, CrossEntropy=1.414062, SmoothL1=0.368501
# INFO:SSDEstimator:[Epoch 10][Batch 299], Speed: 0.620384 samples/sec, CrossEntropy=1.391776, SmoothL1=0.360538
# INFO:SSDEstimator:[Epoch 10][Batch 399], Speed: 0.626904 samples/sec, CrossEntropy=1.391382, SmoothL1=0.358953
# INFO:SSDEstimator:[Epoch 10][Batch 499], Speed: 0.636732 samples/sec, CrossEntropy=1.401298, SmoothL1=0.364754
# INFO:SSDEstimator:[Epoch 10][Batch 599], Speed: 0.666325 samples/sec, CrossEntropy=1.399819, SmoothL1=0.365924
# INFO:SSDEstimator:[Epoch 10] Training cost: 80.850018, CrossEntropy=1.403366, SmoothL1=0.365401
# INFO:SSDEstimator:[Epoch 10] Validation:
# person=0.6623179480131204
# bus=0.9884931245225365
# bird=0.799804159750352
# horse=0.9013892822802071
# dog=0.8722134296307731
# airplane=0.9009349346305868
# train=0.8823351479704324
# cat=0.9294467412204354
# boat=0.8111017639663696
# mAP=0.8608929479983127
# INFO:SSDEstimator:[Epoch 11][Batch 99], Speed: 0.561236 samples/sec, CrossEntropy=1.300599, SmoothL1=0.323343
# INFO:SSDEstimator:[Epoch 11][Batch 199], Speed: 0.641532 samples/sec, CrossEntropy=1.328086, SmoothL1=0.341741
# INFO:SSDEstimator:[Epoch 11][Batch 299], Speed: 0.674516 samples/sec, CrossEntropy=1.338940, SmoothL1=0.346426
# INFO:SSDEstimator:[Epoch 11][Batch 399], Speed: 0.638419 samples/sec, CrossEntropy=1.364353, SmoothL1=0.372369
# INFO:SSDEstimator:[Epoch 11][Batch 499], Speed: 0.659769 samples/sec, CrossEntropy=1.354572, SmoothL1=0.371483
# INFO:SSDEstimator:[Epoch 11][Batch 599], Speed: 0.642174 samples/sec, CrossEntropy=1.359982, SmoothL1=0.369610
# INFO:SSDEstimator:[Epoch 11] Training cost: 78.550268, CrossEntropy=1.360886, SmoothL1=0.365956
# INFO:SSDEstimator:[Epoch 11] Validation:
# person=0.630646009039553
# bus=0.9985096870342773
# bird=0.8575522673113527
# horse=0.9030484569194248
# dog=0.8726281372240581
# airplane=0.8984626832589216
# train=0.8901009067658686
# cat=0.8970953436807096
# boat=0.816956749522938
# mAP=0.8627778045285672
# INFO:SSDEstimator:[Epoch 12][Batch 99], Speed: 0.546511 samples/sec, CrossEntropy=1.388809, SmoothL1=0.377213
# INFO:SSDEstimator:[Epoch 12][Batch 199], Speed: 0.625506 samples/sec, CrossEntropy=1.352068, SmoothL1=0.351151
# INFO:SSDEstimator:[Epoch 12][Batch 299], Speed: 0.663582 samples/sec, CrossEntropy=1.351862, SmoothL1=0.354355
# INFO:SSDEstimator:[Epoch 12][Batch 399], Speed: 0.658978 samples/sec, CrossEntropy=1.351549, SmoothL1=0.351632
# INFO:SSDEstimator:[Epoch 12][Batch 499], Speed: 0.676396 samples/sec, CrossEntropy=1.356207, SmoothL1=0.354375
# INFO:SSDEstimator:[Epoch 12][Batch 599], Speed: 0.633325 samples/sec, CrossEntropy=1.344057, SmoothL1=0.356633
# INFO:SSDEstimator:[Epoch 12] Training cost: 78.839439, CrossEntropy=1.343478, SmoothL1=0.354800
# INFO:SSDEstimator:[Epoch 12] Validation:
# person=0.6601084797655079
# bus=0.9954584382217841
# bird=0.8776462466973418
# horse=0.8999559280347459
# dog=0.8482163657794985
# airplane=0.8950139210450234
# train=0.8631754731673343
# cat=0.9235333007925968
# boat=0.8348951749193866
# mAP=0.8664448142692467
# INFO:SSDEstimator:[Epoch 13][Batch 99], Speed: 0.535121 samples/sec, CrossEntropy=1.380437, SmoothL1=0.352725
# INFO:SSDEstimator:[Epoch 13][Batch 199], Speed: 0.666928 samples/sec, CrossEntropy=1.393797, SmoothL1=0.370380
# INFO:SSDEstimator:[Epoch 13][Batch 299], Speed: 0.638972 samples/sec, CrossEntropy=1.345355, SmoothL1=0.350865
# INFO:SSDEstimator:[Epoch 13][Batch 399], Speed: 0.670405 samples/sec, CrossEntropy=1.334750, SmoothL1=0.348674
# INFO:SSDEstimator:[Epoch 13][Batch 499], Speed: 0.653454 samples/sec, CrossEntropy=1.331090, SmoothL1=0.346661
# INFO:SSDEstimator:[Epoch 13][Batch 599], Speed: 0.643088 samples/sec, CrossEntropy=1.334436, SmoothL1=0.345740
# INFO:SSDEstimator:[Epoch 13] Training cost: 78.816093, CrossEntropy=1.331217, SmoothL1=0.344073
# INFO:SSDEstimator:[Epoch 13] Validation:
# person=0.6373134845413319
# bus=0.9917355371900829
# bird=0.8590764079638279
# horse=0.8902792877225868
# dog=0.846003131271308
# airplane=0.9187721369539552
# train=0.8962634105889288
# cat=0.924539567598134
# boat=0.8070802253565384
# mAP=0.8634514654651881
# INFO:SSDEstimator:[Epoch 14][Batch 99], Speed: 0.563904 samples/sec, CrossEntropy=1.273236, SmoothL1=0.321550
# INFO:SSDEstimator:[Epoch 14][Batch 199], Speed: 0.650939 samples/sec, CrossEntropy=1.271130, SmoothL1=0.330212
# INFO:SSDEstimator:[Epoch 14][Batch 299], Speed: 0.642531 samples/sec, CrossEntropy=1.279245, SmoothL1=0.351536
# INFO:SSDEstimator:[Epoch 14][Batch 399], Speed: 0.684259 samples/sec, CrossEntropy=1.306024, SmoothL1=0.355740
# INFO:SSDEstimator:[Epoch 14][Batch 499], Speed: 0.626565 samples/sec, CrossEntropy=1.310462, SmoothL1=0.356314
# INFO:SSDEstimator:[Epoch 14][Batch 599], Speed: 0.663379 samples/sec, CrossEntropy=1.311318, SmoothL1=0.355128
# INFO:SSDEstimator:[Epoch 14] Training cost: 78.420275, CrossEntropy=1.313700, SmoothL1=0.357361
# INFO:SSDEstimator:[Epoch 14] Validation:
# person=0.6498752494043573
# bus=0.9911141490088861
# bird=0.8643595729218665
# horse=0.8755534538947118
# dog=0.8537982603135404
# airplane=0.9303660436368212
# train=0.8872718857281465
# cat=0.902182028497818
# boat=0.8089293797564552
# mAP=0.8626055581291782
# INFO:SSDEstimator:[Epoch 15][Batch 99], Speed: 0.557126 samples/sec, CrossEntropy=1.247583, SmoothL1=0.332784
# INFO:SSDEstimator:[Epoch 15][Batch 199], Speed: 0.647759 samples/sec, CrossEntropy=1.305259, SmoothL1=0.354226
# INFO:SSDEstimator:[Epoch 15][Batch 299], Speed: 0.675131 samples/sec, CrossEntropy=1.284774, SmoothL1=0.350343
# INFO:SSDEstimator:[Epoch 15][Batch 399], Speed: 0.658085 samples/sec, CrossEntropy=1.296860, SmoothL1=0.352807
# INFO:SSDEstimator:[Epoch 15][Batch 499], Speed: 0.645651 samples/sec, CrossEntropy=1.312253, SmoothL1=0.352884
# INFO:SSDEstimator:[Epoch 15][Batch 599], Speed: 0.654952 samples/sec, CrossEntropy=1.315200, SmoothL1=0.345369
# INFO:SSDEstimator:[Epoch 15] Training cost: 78.180889, CrossEntropy=1.315392, SmoothL1=0.345479
# INFO:SSDEstimator:[Epoch 15] Validation:
# person=0.6719468933932181
# bus=0.9911141490088861
# bird=0.8434606950106417
# horse=0.8880297011822328
# dog=0.8644491241082151
# airplane=0.9067599067599069
# train=0.8946063460349176
# cat=0.9008214986859188
# boat=0.8245336806775682
# mAP=0.8650802216512784
# INFO:SSDEstimator:[Epoch 16][Batch 99], Speed: 0.570016 samples/sec, CrossEntropy=1.301359, SmoothL1=0.341439
# INFO:SSDEstimator:[Epoch 16][Batch 199], Speed: 0.655297 samples/sec, CrossEntropy=1.295815, SmoothL1=0.330506
# INFO:SSDEstimator:[Epoch 16][Batch 299], Speed: 0.685472 samples/sec, CrossEntropy=1.309150, SmoothL1=0.334452
# INFO:SSDEstimator:[Epoch 16][Batch 399], Speed: 0.663476 samples/sec, CrossEntropy=1.301796, SmoothL1=0.330438
# INFO:SSDEstimator:[Epoch 16][Batch 499], Speed: 0.656641 samples/sec, CrossEntropy=1.305727, SmoothL1=0.330544
# INFO:SSDEstimator:[Epoch 16][Batch 599], Speed: 0.648365 samples/sec, CrossEntropy=1.305796, SmoothL1=0.331627
# INFO:SSDEstimator:[Epoch 16] Training cost: 77.437673, CrossEntropy=1.304976, SmoothL1=0.330918
# INFO:SSDEstimator:[Epoch 16] Validation:
# person=0.6393558154867256
# bus=0.9917355371900829
# bird=0.8506368068792798
# horse=0.8949070583221322
# dog=0.8569226517908449
# airplane=0.9039860690346129
# train=0.8822694076125612
# cat=0.919371423292815
# boat=0.779595853421672
# mAP=0.8576422914478585
# INFO:SSDEstimator:[Epoch 17][Batch 99], Speed: 0.554227 samples/sec, CrossEntropy=1.234506, SmoothL1=0.339809
# INFO:SSDEstimator:[Epoch 17][Batch 199], Speed: 0.670139 samples/sec, CrossEntropy=1.266103, SmoothL1=0.339002
# INFO:SSDEstimator:[Epoch 17][Batch 299], Speed: 0.642691 samples/sec, CrossEntropy=1.256456, SmoothL1=0.333827
# INFO:SSDEstimator:[Epoch 17][Batch 399], Speed: 0.639838 samples/sec, CrossEntropy=1.270383, SmoothL1=0.331293
# INFO:SSDEstimator:[Epoch 17][Batch 499], Speed: 0.643821 samples/sec, CrossEntropy=1.264278, SmoothL1=0.325581
# INFO:SSDEstimator:[Epoch 17][Batch 599], Speed: 0.631335 samples/sec, CrossEntropy=1.265188, SmoothL1=0.326816
# INFO:SSDEstimator:[Epoch 17] Training cost: 79.185355, CrossEntropy=1.267303, SmoothL1=0.328581
# INFO:SSDEstimator:[Epoch 17] Validation:
# person=0.6383136685820006
# bus=0.9923664122137407
# bird=0.845252909627955
# horse=0.9003326770317064
# dog=0.8269805779197097
# airplane=0.9058010939433866
# train=0.8923019552509576
# cat=0.898479049040847
# boat=0.7857500259459392
# mAP=0.8539531521729159
# INFO:SSDEstimator:[Epoch 18][Batch 99], Speed: 0.541934 samples/sec, CrossEntropy=1.275496, SmoothL1=0.318621
# INFO:SSDEstimator:[Epoch 18][Batch 199], Speed: 0.677608 samples/sec, CrossEntropy=1.269333, SmoothL1=0.315935
# INFO:SSDEstimator:[Epoch 18][Batch 299], Speed: 0.649306 samples/sec, CrossEntropy=1.250427, SmoothL1=0.312908
# INFO:SSDEstimator:[Epoch 18][Batch 399], Speed: 0.664194 samples/sec, CrossEntropy=1.238307, SmoothL1=0.318438
# INFO:SSDEstimator:[Epoch 18][Batch 499], Speed: 0.645766 samples/sec, CrossEntropy=1.249198, SmoothL1=0.316933
# INFO:SSDEstimator:[Epoch 18][Batch 599], Speed: 0.661592 samples/sec, CrossEntropy=1.252712, SmoothL1=0.318559
# INFO:SSDEstimator:[Epoch 18] Training cost: 78.167735, CrossEntropy=1.245501, SmoothL1=0.316615
# INFO:SSDEstimator:[Epoch 18] Validation:
# person=0.6402005332141242
# bus=0.9398207426376443
# bird=0.8680914981874892
# horse=0.8919925627876493
# dog=0.8612309994155609
# airplane=0.9009478288499632
# train=0.8780885856780821
# cat=0.8966094918024701
# boat=0.8314790667921726
# mAP=0.8564957010405729
# INFO:SSDEstimator:[Epoch 19][Batch 99], Speed: 0.577046 samples/sec, CrossEntropy=1.248085, SmoothL1=0.315527
# INFO:SSDEstimator:[Epoch 19][Batch 199], Speed: 0.672778 samples/sec, CrossEntropy=1.209130, SmoothL1=0.313944
# INFO:SSDEstimator:[Epoch 19][Batch 299], Speed: 0.660259 samples/sec, CrossEntropy=1.234889, SmoothL1=0.321897
# INFO:SSDEstimator:[Epoch 19][Batch 399], Speed: 0.666787 samples/sec, CrossEntropy=1.230589, SmoothL1=0.320966
# INFO:SSDEstimator:[Epoch 19][Batch 499], Speed: 0.644820 samples/sec, CrossEntropy=1.233156, SmoothL1=0.317996
# INFO:SSDEstimator:[Epoch 19][Batch 599], Speed: 0.682611 samples/sec, CrossEntropy=1.246051, SmoothL1=0.323024
# INFO:SSDEstimator:[Epoch 19] Training cost: 76.806637, CrossEntropy=1.252228, SmoothL1=0.331248
# INFO:SSDEstimator:[Epoch 19] Validation:
# person=0.6381061684055288
# bus=0.9828009828009829
# bird=0.8435848848042699
# horse=0.8924364671872977
# dog=0.8624390021567441
# airplane=0.9280019445794846
# train=0.9019513207781449
# cat=0.8920457625531623
# boat=0.8291372343141423
# mAP=0.863389307508862
# INFO:SSDEstimator:[Epoch 20][Batch 99], Speed: 0.580684 samples/sec, CrossEntropy=1.271276, SmoothL1=0.299002
# INFO:SSDEstimator:[Epoch 20][Batch 199], Speed: 0.645416 samples/sec, CrossEntropy=1.260624, SmoothL1=0.297200
# INFO:SSDEstimator:[Epoch 20][Batch 299], Speed: 0.652367 samples/sec, CrossEntropy=1.246825, SmoothL1=0.305932
# INFO:SSDEstimator:[Epoch 20][Batch 399], Speed: 0.629982 samples/sec, CrossEntropy=1.239815, SmoothL1=0.304042
# INFO:SSDEstimator:[Epoch 20][Batch 499], Speed: 0.651164 samples/sec, CrossEntropy=1.242626, SmoothL1=0.305500
# INFO:SSDEstimator:[Epoch 20][Batch 599], Speed: 0.629734 samples/sec, CrossEntropy=1.241955, SmoothL1=0.314771
# INFO:SSDEstimator:[Epoch 20] Training cost: 78.997107, CrossEntropy=1.240083, SmoothL1=0.312181
# INFO:SSDEstimator:[Epoch 20] Validation:
# person=0.6805028093076289
# bus=0.9851109877284627
# bird=0.8753973188613375
# horse=0.8903150406504067
# dog=0.8639500768961794
# airplane=0.905844155844156
# train=0.8843700592906212
# cat=0.9019922903418051
# boat=0.8205860309686961
# mAP=0.867563196654366
# INFO:SSDEstimator:[Epoch 21][Batch 99], Speed: 0.559146 samples/sec, CrossEntropy=1.156390, SmoothL1=0.294126
# INFO:SSDEstimator:[Epoch 21][Batch 199], Speed: 0.646824 samples/sec, CrossEntropy=1.159486, SmoothL1=0.301509
# INFO:SSDEstimator:[Epoch 21][Batch 299], Speed: 0.648588 samples/sec, CrossEntropy=1.150833, SmoothL1=0.298677
# INFO:SSDEstimator:[Epoch 21][Batch 399], Speed: 0.633169 samples/sec, CrossEntropy=1.170153, SmoothL1=0.305495
# INFO:SSDEstimator:[Epoch 21][Batch 499], Speed: 0.660217 samples/sec, CrossEntropy=1.196751, SmoothL1=0.308463
# INFO:SSDEstimator:[Epoch 21][Batch 599], Speed: 0.639542 samples/sec, CrossEntropy=1.201819, SmoothL1=0.309031
# INFO:SSDEstimator:[Epoch 21] Training cost: 79.134145, CrossEntropy=1.198584, SmoothL1=0.307536
# INFO:SSDEstimator:[Epoch 21] Validation:
# person=0.6502915309060131
# bus=0.9887193098871933
# bird=0.8662115741063108
# horse=0.9028213166144202
# dog=0.851389623683168
# airplane=0.9267878004140642
# train=0.8859732314291188
# cat=0.8987776928953402
# boat=0.7929835779384183
# mAP=0.862661739763783
# INFO:SSDEstimator:[Epoch 22][Batch 99], Speed: 0.539111 samples/sec, CrossEntropy=1.122801, SmoothL1=0.279557
# INFO:SSDEstimator:[Epoch 22][Batch 199], Speed: 0.670749 samples/sec, CrossEntropy=1.148622, SmoothL1=0.286600
# INFO:SSDEstimator:[Epoch 22][Batch 299], Speed: 0.646072 samples/sec, CrossEntropy=1.167524, SmoothL1=0.287367
# INFO:SSDEstimator:[Epoch 22][Batch 399], Speed: 0.658291 samples/sec, CrossEntropy=1.197441, SmoothL1=0.295717
# INFO:SSDEstimator:[Epoch 22][Batch 499], Speed: 0.643105 samples/sec, CrossEntropy=1.189910, SmoothL1=0.291159
# INFO:SSDEstimator:[Epoch 22][Batch 599], Speed: 0.654080 samples/sec, CrossEntropy=1.199277, SmoothL1=0.291239
# INFO:SSDEstimator:[Epoch 22] Training cost: 78.837244, CrossEntropy=1.205732, SmoothL1=0.297362
# INFO:SSDEstimator:[Epoch 22] Validation:
# person=0.6707469973458844
# bus=0.9864603481624761
# bird=0.8631882100002907
# horse=0.9171727874774234
# dog=0.8545276315907526
# airplane=0.8926073926073927
# train=0.8565525948108428
# cat=0.9032502011263075
# boat=0.7837886795525852
# mAP=0.8586994269637729
# INFO:SSDEstimator:[Epoch 23][Batch 99], Speed: 0.529379 samples/sec, CrossEntropy=1.202682, SmoothL1=0.300725
# INFO:SSDEstimator:[Epoch 23][Batch 199], Speed: 0.655352 samples/sec, CrossEntropy=1.185931, SmoothL1=0.301368
# INFO:SSDEstimator:[Epoch 23][Batch 299], Speed: 0.638442 samples/sec, CrossEntropy=1.188439, SmoothL1=0.302908
# INFO:SSDEstimator:[Epoch 23][Batch 399], Speed: 0.677740 samples/sec, CrossEntropy=1.177122, SmoothL1=0.296713
# INFO:SSDEstimator:[Epoch 23][Batch 499], Speed: 0.628452 samples/sec, CrossEntropy=1.185483, SmoothL1=0.298090
# INFO:SSDEstimator:[Epoch 23][Batch 599], Speed: 0.680592 samples/sec, CrossEntropy=1.188966, SmoothL1=0.305057
# INFO:SSDEstimator:[Epoch 23] Training cost: 79.116174, CrossEntropy=1.184523, SmoothL1=0.307394
# INFO:SSDEstimator:[Epoch 23] Validation:
# person=0.6575142387680144
# bus=0.9736242929161442
# bird=0.8837130709096729
# horse=0.8905456048794107
# dog=0.871446902575179
# airplane=0.8927216332055041
# train=0.8883595651996906
# cat=0.9340419467538114
# boat=0.8347978233747704
# mAP=0.8696405642869108
# INFO:SSDEstimator:[Epoch 23] Current best map: 0.869641 vs previous 0.869160, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 24][Batch 99], Speed: 0.560625 samples/sec, CrossEntropy=1.137823, SmoothL1=0.303868
# INFO:SSDEstimator:[Epoch 24][Batch 199], Speed: 0.637139 samples/sec, CrossEntropy=1.167194, SmoothL1=0.310193
# INFO:SSDEstimator:[Epoch 24][Batch 299], Speed: 0.669194 samples/sec, CrossEntropy=1.171000, SmoothL1=0.303552
# INFO:SSDEstimator:[Epoch 24][Batch 399], Speed: 0.654961 samples/sec, CrossEntropy=1.156290, SmoothL1=0.299209
# INFO:SSDEstimator:[Epoch 24][Batch 499], Speed: 0.660162 samples/sec, CrossEntropy=1.149889, SmoothL1=0.297031
# INFO:SSDEstimator:[Epoch 24][Batch 599], Speed: 0.675495 samples/sec, CrossEntropy=1.152870, SmoothL1=0.297279
# INFO:SSDEstimator:[Epoch 24] Training cost: 77.830624, CrossEntropy=1.154643, SmoothL1=0.298072
# INFO:SSDEstimator:[Epoch 24] Validation:
# person=0.673448685525879
# bus=0.9856558429331921
# bird=0.8611226540657205
# horse=0.8953404742835428
# dog=0.8628646054545042
# airplane=0.8986579586812435
# train=0.9293546292204445
# cat=0.9277843125695393
# boat=0.8177241355290739
# mAP=0.8724392553625712
# INFO:SSDEstimator:[Epoch 24] Current best map: 0.872439 vs previous 0.869641, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 25][Batch 99], Speed: 0.527758 samples/sec, CrossEntropy=1.182183, SmoothL1=0.293183
# INFO:SSDEstimator:[Epoch 25][Batch 199], Speed: 0.657911 samples/sec, CrossEntropy=1.147220, SmoothL1=0.277669
# INFO:SSDEstimator:[Epoch 25][Batch 299], Speed: 0.671286 samples/sec, CrossEntropy=1.154166, SmoothL1=0.280912
# INFO:SSDEstimator:[Epoch 25][Batch 399], Speed: 0.648627 samples/sec, CrossEntropy=1.159803, SmoothL1=0.288690
# INFO:SSDEstimator:[Epoch 25][Batch 499], Speed: 0.683026 samples/sec, CrossEntropy=1.162150, SmoothL1=0.291854
# INFO:SSDEstimator:[Epoch 25][Batch 599], Speed: 0.640194 samples/sec, CrossEntropy=1.173735, SmoothL1=0.293351
# INFO:SSDEstimator:[Epoch 25] Training cost: 78.651005, CrossEntropy=1.170390, SmoothL1=0.291688
# INFO:SSDEstimator:[Epoch 25] Validation:
# person=0.6956776195877048
# bus=0.994318181818182
# bird=0.8485650537042608
# horse=0.888927815960202
# dog=0.8676073594652431
# airplane=0.9392203407861175
# train=0.8937648373132245
# cat=0.9034122098292344
# boat=0.8275703899418623
# mAP=0.8732293120451147
# INFO:SSDEstimator:[Epoch 25] Current best map: 0.873229 vs previous 0.872439, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 26][Batch 99], Speed: 0.538023 samples/sec, CrossEntropy=1.177284, SmoothL1=0.309431
# INFO:SSDEstimator:[Epoch 26][Batch 199], Speed: 0.667809 samples/sec, CrossEntropy=1.178745, SmoothL1=0.314001
# INFO:SSDEstimator:[Epoch 26][Batch 299], Speed: 0.648527 samples/sec, CrossEntropy=1.197357, SmoothL1=0.302365
# INFO:SSDEstimator:[Epoch 26][Batch 399], Speed: 0.661477 samples/sec, CrossEntropy=1.219562, SmoothL1=0.310825
# INFO:SSDEstimator:[Epoch 26][Batch 499], Speed: 0.656815 samples/sec, CrossEntropy=1.216239, SmoothL1=0.307997
# INFO:SSDEstimator:[Epoch 26][Batch 599], Speed: 0.647533 samples/sec, CrossEntropy=1.229502, SmoothL1=0.308038
# INFO:SSDEstimator:[Epoch 26] Training cost: 78.492426, CrossEntropy=1.223947, SmoothL1=0.305756
# INFO:SSDEstimator:[Epoch 26] Validation:
# person=0.6785458981788075
# bus=0.981818181818182
# bird=0.8465687280332241
# horse=0.8889852333213174
# dog=0.8627326367479657
# airplane=0.9185997385644988
# train=0.8912259615384617
# cat=0.8989223226801755
# boat=0.778273281267057
# mAP=0.8606302202388545
# INFO:SSDEstimator:[Epoch 27][Batch 99], Speed: 0.558774 samples/sec, CrossEntropy=1.207852, SmoothL1=0.311849
# INFO:SSDEstimator:[Epoch 27][Batch 199], Speed: 0.636122 samples/sec, CrossEntropy=1.127161, SmoothL1=0.277807
# INFO:SSDEstimator:[Epoch 27][Batch 299], Speed: 0.660290 samples/sec, CrossEntropy=1.144768, SmoothL1=0.289174
# INFO:SSDEstimator:[Epoch 27][Batch 399], Speed: 0.654549 samples/sec, CrossEntropy=1.137688, SmoothL1=0.289849
# INFO:SSDEstimator:[Epoch 27][Batch 499], Speed: 0.645387 samples/sec, CrossEntropy=1.157795, SmoothL1=0.291199
# INFO:SSDEstimator:[Epoch 27][Batch 599], Speed: 0.678827 samples/sec, CrossEntropy=1.166123, SmoothL1=0.290976
# INFO:SSDEstimator:[Epoch 27] Training cost: 78.263454, CrossEntropy=1.163883, SmoothL1=0.289809
# INFO:SSDEstimator:[Epoch 27] Validation:
# person=0.6657265138306002
# bus=0.994844549390004
# bird=0.8777729229124249
# horse=0.895827182718272
# dog=0.8697245647531181
# airplane=0.886467940325387
# train=0.8807314213564214
# cat=0.9028213166144202
# boat=0.806781802185483
# mAP=0.8645220237873479
# INFO:SSDEstimator:[Epoch 28][Batch 99], Speed: 0.565358 samples/sec, CrossEntropy=1.110780, SmoothL1=0.275602
# INFO:SSDEstimator:[Epoch 28][Batch 199], Speed: 0.642656 samples/sec, CrossEntropy=1.137595, SmoothL1=0.282523
# INFO:SSDEstimator:[Epoch 28][Batch 299], Speed: 0.679246 samples/sec, CrossEntropy=1.156968, SmoothL1=0.293294
# INFO:SSDEstimator:[Epoch 28][Batch 399], Speed: 0.642410 samples/sec, CrossEntropy=1.165255, SmoothL1=0.297870
# INFO:SSDEstimator:[Epoch 28][Batch 499], Speed: 0.653819 samples/sec, CrossEntropy=1.161136, SmoothL1=0.295526
# INFO:SSDEstimator:[Epoch 28][Batch 599], Speed: 0.642314 samples/sec, CrossEntropy=1.162677, SmoothL1=0.299321
# INFO:SSDEstimator:[Epoch 28] Training cost: 78.408219, CrossEntropy=1.161709, SmoothL1=0.299658
# INFO:SSDEstimator:[Epoch 28] Validation:
# person=0.6677412087171984
# bus=0.9870129870129872
# bird=0.8611031452857474
# horse=0.897040308022399
# dog=0.8678558016103505
# airplane=0.9428917388839111
# train=0.8912107690909535
# cat=0.904204831459845
# boat=0.8368007158561037
# mAP=0.872873500659944
# INFO:SSDEstimator:[Epoch 29][Batch 99], Speed: 0.557585 samples/sec, CrossEntropy=1.039989, SmoothL1=0.269542
# INFO:SSDEstimator:[Epoch 29][Batch 199], Speed: 0.639162 samples/sec, CrossEntropy=1.089444, SmoothL1=0.269932
# INFO:SSDEstimator:[Epoch 29][Batch 299], Speed: 0.646897 samples/sec, CrossEntropy=1.109596, SmoothL1=0.274140
# INFO:SSDEstimator:[Epoch 29][Batch 399], Speed: 0.642224 samples/sec, CrossEntropy=1.124887, SmoothL1=0.281273
# INFO:SSDEstimator:[Epoch 29][Batch 499], Speed: 0.648589 samples/sec, CrossEntropy=1.144354, SmoothL1=0.284076
# INFO:SSDEstimator:[Epoch 29][Batch 599], Speed: 0.627534 samples/sec, CrossEntropy=1.154276, SmoothL1=0.284013
# INFO:SSDEstimator:[Epoch 29] Training cost: 79.637026, CrossEntropy=1.153794, SmoothL1=0.284096
# INFO:SSDEstimator:[Epoch 29] Validation:
# person=0.6618960089906869
# bus=0.9685431287641234
# bird=0.8672923718378265
# horse=0.8896559780438942
# dog=0.8433470667943996
# airplane=0.9074380165289258
# train=0.8866638764137993
# cat=0.9049440658351551
# boat=0.7858584622298183
# mAP=0.8572932194931809
# INFO:SSDEstimator:[Epoch 30][Batch 99], Speed: 0.539531 samples/sec, CrossEntropy=1.157212, SmoothL1=0.290316
# INFO:SSDEstimator:[Epoch 30][Batch 199], Speed: 0.668211 samples/sec, CrossEntropy=1.159417, SmoothL1=0.297940
# INFO:SSDEstimator:[Epoch 30][Batch 299], Speed: 0.652227 samples/sec, CrossEntropy=1.166801, SmoothL1=0.294198
# INFO:SSDEstimator:[Epoch 30][Batch 399], Speed: 0.649745 samples/sec, CrossEntropy=1.155791, SmoothL1=0.296541
# INFO:SSDEstimator:[Epoch 30][Batch 499], Speed: 0.656785 samples/sec, CrossEntropy=1.149507, SmoothL1=0.295704
# INFO:SSDEstimator:[Epoch 30][Batch 599], Speed: 0.658381 samples/sec, CrossEntropy=1.152901, SmoothL1=0.299017
# INFO:SSDEstimator:[Epoch 30] Training cost: 78.488186, CrossEntropy=1.148116, SmoothL1=0.296174
# INFO:SSDEstimator:[Epoch 30] Validation:
# person=0.6848737827173235
# bus=0.9963636363636366
# bird=0.8758368815256261
# horse=0.9009660290448469
# dog=0.8835497619051571
# airplane=0.9654036533765501
# train=0.9024318058501457
# cat=0.9033554165133113
# boat=0.8278094647829791
# mAP=0.8822878257866197
# INFO:SSDEstimator:[Epoch 30] Current best map: 0.882288 vs previous 0.873229, saved to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_0/best_checkpoint.pkl
# INFO:SSDEstimator:[Epoch 31][Batch 99], Speed: 0.536175 samples/sec, CrossEntropy=1.083718, SmoothL1=0.290870
# INFO:SSDEstimator:[Epoch 31][Batch 199], Speed: 0.657044 samples/sec, CrossEntropy=1.092103, SmoothL1=0.278890
# INFO:SSDEstimator:[Epoch 31][Batch 299], Speed: 0.645647 samples/sec, CrossEntropy=1.093963, SmoothL1=0.278439
# INFO:SSDEstimator:[Epoch 31][Batch 399], Speed: 0.668006 samples/sec, CrossEntropy=1.119807, SmoothL1=0.286409
# INFO:SSDEstimator:[Epoch 31][Batch 499], Speed: 0.631190 samples/sec, CrossEntropy=1.124272, SmoothL1=0.288758
# INFO:SSDEstimator:[Epoch 31][Batch 599], Speed: 0.669316 samples/sec, CrossEntropy=1.128893, SmoothL1=0.288758
# INFO:SSDEstimator:[Epoch 31] Training cost: 78.942461, CrossEntropy=1.128012, SmoothL1=0.288652
# INFO:SSDEstimator:[Epoch 31] Validation:
# person=0.6443629142284947
# bus=0.9948735475051266
# bird=0.8679583857003212
# horse=0.9324190917675339
# dog=0.8519274993265533
# airplane=0.9040363408826805
# train=0.8977192992493565
# cat=0.929049487510837
# boat=0.8153169376766737
# mAP=0.8708515004275085
# INFO:SSDEstimator:[Epoch 32][Batch 99], Speed: 0.559349 samples/sec, CrossEntropy=1.128159, SmoothL1=0.260427
# INFO:SSDEstimator:[Epoch 32][Batch 199], Speed: 0.646078 samples/sec, CrossEntropy=1.157078, SmoothL1=0.270040
# INFO:SSDEstimator:[Epoch 32][Batch 299], Speed: 0.658172 samples/sec, CrossEntropy=1.126942, SmoothL1=0.260538
# INFO:SSDEstimator:[Epoch 32][Batch 399], Speed: 0.628822 samples/sec, CrossEntropy=1.129261, SmoothL1=0.269949
# INFO:SSDEstimator:[Epoch 32][Batch 499], Speed: 0.677801 samples/sec, CrossEntropy=1.127722, SmoothL1=0.271133
# INFO:SSDEstimator:[Epoch 32][Batch 599], Speed: 0.658240 samples/sec, CrossEntropy=1.137211, SmoothL1=0.275484
# INFO:SSDEstimator:[Epoch 32] Training cost: 78.367313, CrossEntropy=1.141273, SmoothL1=0.276519
# INFO:SSDEstimator:[Epoch 32] Validation:
# person=0.6533034572406997
# bus=0.9917355371900829
# bird=0.8744716707882851
# horse=0.8934817323541865
# dog=0.8583927800214747
# airplane=0.904233059713504
# train=0.8889676217253536
# cat=0.9035573122529645
# boat=0.8387448134787392
# mAP=0.8674319983072544
# INFO:SSDEstimator:[Epoch 33][Batch 99], Speed: 0.569384 samples/sec, CrossEntropy=1.129162, SmoothL1=0.283490
# INFO:SSDEstimator:[Epoch 33][Batch 199], Speed: 0.644641 samples/sec, CrossEntropy=1.076359, SmoothL1=0.266393
# INFO:SSDEstimator:[Epoch 33][Batch 299], Speed: 0.684959 samples/sec, CrossEntropy=1.104959, SmoothL1=0.275707
# INFO:SSDEstimator:[Epoch 33][Batch 399], Speed: 0.635323 samples/sec, CrossEntropy=1.096063, SmoothL1=0.272443
# INFO:SSDEstimator:[Epoch 33][Batch 499], Speed: 0.671408 samples/sec, CrossEntropy=1.100131, SmoothL1=0.271785
# INFO:SSDEstimator:[Epoch 33][Batch 599], Speed: 0.629958 samples/sec, CrossEntropy=1.099144, SmoothL1=0.270867
# INFO:SSDEstimator:[Epoch 33] Training cost: 78.225589, CrossEntropy=1.105328, SmoothL1=0.276495
# INFO:SSDEstimator:[Epoch 33] Validation:
# person=0.6400197032765261
# bus=0.9963636363636366
# bird=0.8308808392801004
# horse=0.8890311023217254
# dog=0.86587157143867
# airplane=0.9022630756503356
# train=0.9202874177758096
# cat=0.9008300395256919
# boat=0.7959932415725856
# mAP=0.8601711808005645
# INFO:SSDEstimator:[Epoch 34][Batch 99], Speed: 0.562938 samples/sec, CrossEntropy=1.074276, SmoothL1=0.256838
# INFO:SSDEstimator:[Epoch 34][Batch 199], Speed: 0.665436 samples/sec, CrossEntropy=1.074719, SmoothL1=0.268680
# INFO:SSDEstimator:[Epoch 34][Batch 299], Speed: 0.639880 samples/sec, CrossEntropy=1.112376, SmoothL1=0.275476
# INFO:SSDEstimator:[Epoch 34][Batch 399], Speed: 0.650485 samples/sec, CrossEntropy=1.112318, SmoothL1=0.278790
# INFO:SSDEstimator:[Epoch 34][Batch 499], Speed: 0.658260 samples/sec, CrossEntropy=1.114271, SmoothL1=0.277254
# INFO:SSDEstimator:[Epoch 34][Batch 599], Speed: 0.651632 samples/sec, CrossEntropy=1.122706, SmoothL1=0.283578
# INFO:SSDEstimator:[Epoch 34] Training cost: 78.262563, CrossEntropy=1.120345, SmoothL1=0.283760
# INFO:SSDEstimator:[Epoch 34] Validation:
# person=0.6722137123915803
# bus=0.9881422924901188
# bird=0.8644426491595266
# horse=0.8871702060713923
# dog=0.8786150650169359
# airplane=0.8950205476453297
# train=0.899008954400075
# cat=0.9331016297711319
# boat=0.7697345191071658
# mAP=0.8652721751170285
# INFO:SSDEstimator:[Epoch 35][Batch 99], Speed: 0.548948 samples/sec, CrossEntropy=1.044930, SmoothL1=0.255344
# INFO:SSDEstimator:[Epoch 35][Batch 199], Speed: 0.682071 samples/sec, CrossEntropy=1.054910, SmoothL1=0.255846
# INFO:SSDEstimator:[Epoch 35][Batch 299], Speed: 0.626132 samples/sec, CrossEntropy=1.069422, SmoothL1=0.255515
# INFO:SSDEstimator:[Epoch 35][Batch 399], Speed: 0.664339 samples/sec, CrossEntropy=1.086169, SmoothL1=0.267246
# INFO:SSDEstimator:[Epoch 35][Batch 499], Speed: 0.639017 samples/sec, CrossEntropy=1.088194, SmoothL1=0.272218
# INFO:SSDEstimator:[Epoch 35][Batch 599], Speed: 0.648850 samples/sec, CrossEntropy=1.083478, SmoothL1=0.274578
# INFO:SSDEstimator:[Epoch 35] Training cost: 78.797403, CrossEntropy=1.081536, SmoothL1=0.275505
# INFO:SSDEstimator:[Epoch 35] Validation:
# person=0.654724865533272
# bus=0.9799291617473438
# bird=0.8239603539367187
# horse=0.8955240636631346
# dog=0.857295589212232
# airplane=0.8960406621362537
# train=0.890624272119663
# cat=0.8987435328898745
# boat=0.8049712096117316
# mAP=0.8557570789833582
# INFO:SSDEstimator:[Epoch 36][Batch 99], Speed: 0.557961 samples/sec, CrossEntropy=1.065524, SmoothL1=0.276415
# INFO:SSDEstimator:[Epoch 36][Batch 199], Speed: 0.638767 samples/sec, CrossEntropy=1.062750, SmoothL1=0.269873
# INFO:SSDEstimator:[Epoch 36][Batch 299], Speed: 0.650778 samples/sec, CrossEntropy=1.054173, SmoothL1=0.268539
# INFO:SSDEstimator:[Epoch 36][Batch 399], Speed: 0.626338 samples/sec, CrossEntropy=1.053561, SmoothL1=0.265100
# INFO:SSDEstimator:[Epoch 36][Batch 499], Speed: 0.663004 samples/sec, CrossEntropy=1.066587, SmoothL1=0.268644
# INFO:SSDEstimator:[Epoch 36][Batch 599], Speed: 0.665584 samples/sec, CrossEntropy=1.069223, SmoothL1=0.268157
# INFO:SSDEstimator:[Epoch 36] Training cost: 78.891865, CrossEntropy=1.080996, SmoothL1=0.270674
# INFO:SSDEstimator:[Epoch 36] Validation:
# person=0.6575959881304124
# bus=0.9881422924901188
# bird=0.843096613016644
# horse=0.9012824426467759
# dog=0.8541049954594824
# airplane=0.9388682831283838
# train=0.8926021854733538
# cat=0.8871882423157518
# boat=0.8109311185416599
# mAP=0.863756906800287
# INFO:SSDEstimator:[Epoch 37][Batch 99], Speed: 0.567754 samples/sec, CrossEntropy=1.030814, SmoothL1=0.279174
# INFO:SSDEstimator:[Epoch 37][Batch 199], Speed: 0.638707 samples/sec, CrossEntropy=1.064849, SmoothL1=0.276009
# INFO:SSDEstimator:[Epoch 37][Batch 299], Speed: 0.682896 samples/sec, CrossEntropy=1.046223, SmoothL1=0.265040
# INFO:SSDEstimator:[Epoch 37][Batch 399], Speed: 0.631209 samples/sec, CrossEntropy=1.063350, SmoothL1=0.265939
# INFO:SSDEstimator:[Epoch 37][Batch 499], Speed: 0.676416 samples/sec, CrossEntropy=1.072413, SmoothL1=0.268765
# INFO:SSDEstimator:[Epoch 37][Batch 599], Speed: 0.641548 samples/sec, CrossEntropy=1.075198, SmoothL1=0.270833
# INFO:SSDEstimator:[Epoch 37] Training cost: 78.326496, CrossEntropy=1.075285, SmoothL1=0.269000
# INFO:SSDEstimator:[Epoch 37] Validation:
# person=0.6609759468914932
# bus=0.9837253655435475
# bird=0.8682286971760655
# horse=0.883229663193579
# dog=0.8826086401679704
# airplane=0.9295379485246675
# train=0.8891083642090276
# cat=0.9043478260869566
# boat=0.832833241577255
# mAP=0.8705106325967292
# INFO:SSDEstimator:[Epoch 38][Batch 99], Speed: 0.560639 samples/sec, CrossEntropy=1.045664, SmoothL1=0.264600
# INFO:SSDEstimator:[Epoch 38][Batch 199], Speed: 0.655958 samples/sec, CrossEntropy=1.071889, SmoothL1=0.251599
# INFO:SSDEstimator:[Epoch 38][Batch 299], Speed: 0.674093 samples/sec, CrossEntropy=1.066438, SmoothL1=0.254193
# INFO:SSDEstimator:[Epoch 38][Batch 399], Speed: 0.643285 samples/sec, CrossEntropy=1.080160, SmoothL1=0.257436
# INFO:SSDEstimator:[Epoch 38][Batch 499], Speed: 0.667431 samples/sec, CrossEntropy=1.074632, SmoothL1=0.255512
# INFO:SSDEstimator:[Epoch 38][Batch 599], Speed: 0.648224 samples/sec, CrossEntropy=1.078169, SmoothL1=0.260907
# INFO:SSDEstimator:[Epoch 38] Training cost: 77.898070, CrossEntropy=1.077682, SmoothL1=0.260934
# INFO:SSDEstimator:[Epoch 38] Validation:
# person=0.6959571557085488
# bus=0.986504290852117
# bird=0.8513462477439233
# horse=0.8919684459488169
# dog=0.8725135034671894
# airplane=0.9495593710875893
# train=0.8829257336707211
# cat=0.9388153669478355
# boat=0.824487416901985
# mAP=0.877119725814303
# INFO:SSDEstimator:[Epoch 39][Batch 99], Speed: 0.544051 samples/sec, CrossEntropy=1.083698, SmoothL1=0.282184
# INFO:SSDEstimator:[Epoch 39][Batch 199], Speed: 0.662088 samples/sec, CrossEntropy=1.089391, SmoothL1=0.273382
# INFO:SSDEstimator:[Epoch 39][Batch 299], Speed: 0.647751 samples/sec, CrossEntropy=1.074452, SmoothL1=0.265248
# INFO:SSDEstimator:[Epoch 39][Batch 399], Speed: 0.664931 samples/sec, CrossEntropy=1.057648, SmoothL1=0.261415
# ...
# INFO:YOLOv3Estimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:YOLOv3Estimator:root.num_workers     4 != 12
# INFO:YOLOv3Estimator:}
# INFO:YOLOv3Estimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_2/config.yaml
# INFO:YOLOv3Estimator:Using transfer learning from yolo3_darknet53_coco, the other network parameters are ignored.
# Downloading /root/.mxnet/models/yolo3_darknet53_coco-09767802.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/yolo3_darknet53_coco-09767802.zip...
#   0%|          | 0/224190 [00:00<?, ?KB/s]
#   0%|          | 32/224190 [00:00<18:09, 205.71KB/s]
#   0%|          | 101/224190 [00:00<10:56, 341.09KB/s]
#   0%|          | 238/224190 [00:00<06:26, 579.72KB/s]
#   0%|          | 510/224190 [00:00<03:37, 1026.08KB/s]
#   0%|          | 1064/224190 [00:00<01:56, 1912.94KB/s]
#   1%|          | 2184/224190 [00:00<01:00, 3650.67KB/s]
#   2%|▏         | 4408/224190 [00:01<00:31, 7031.72KB/s]
#   4%|▍         | 8872/224190 [00:01<00:15, 13716.20KB/s]
#   6%|▌         | 13944/224190 [00:01<00:10, 19374.61KB/s]
#   8%|▊         | 18392/224190 [00:01<00:09, 22023.15KB/s]
#  10%|█         | 23496/224190 [00:01<00:07, 25086.93KB/s]
#  13%|█▎        | 28600/224190 [00:01<00:07, 27186.11KB/s]
#  15%|█▍        | 33416/224190 [00:02<00:06, 28091.40KB/s]
#  17%|█▋        | 38120/224190 [00:02<00:06, 28538.63KB/s]
#  19%|█▉        | 43160/224190 [00:02<00:06, 29456.18KB/s]
#  21%|██▏       | 48168/224190 [00:02<00:05, 30056.43KB/s]
#  24%|██▎       | 53016/224190 [00:02<00:05, 30131.10KB/s]
#  26%|██▌       | 57976/224190 [00:02<00:05, 30474.49KB/s]
#  28%|██▊       | 63032/224190 [00:03<00:05, 30854.23KB/s]
#  30%|███       | 68088/224190 [00:03<00:05, 31110.72KB/s]
#  33%|███▎      | 73096/224190 [00:03<00:04, 31201.19KB/s]
#  35%|███▍      | 77960/224190 [00:03<00:04, 30996.67KB/s]
#  37%|███▋      | 83032/224190 [00:03<00:04, 31242.43KB/s]
#  39%|███▉      | 88072/224190 [00:03<00:04, 31350.83KB/s]
#  42%|████▏     | 93160/224190 [00:03<00:04, 31534.67KB/s]
#  44%|████▍     | 98232/224190 [00:04<00:03, 31610.33KB/s]
#  46%|████▌     | 103272/224190 [00:04<00:03, 31569.00KB/s]
#  48%|████▊     | 108248/224190 [00:04<00:03, 31389.65KB/s]
#  51%|█████     | 113304/224190 [00:04<00:03, 31495.08KB/s]
#  53%|█████▎    | 118328/224190 [00:04<00:03, 31580.24KB/s]
#  55%|█████▌    | 123336/224190 [00:04<00:03, 31542.96KB/s]
#  57%|█████▋    | 128392/224190 [00:05<00:03, 31513.85KB/s]
#  60%|█████▉    | 133464/224190 [00:05<00:02, 31605.23KB/s]
#  62%|██████▏   | 138536/224190 [00:05<00:02, 31673.56KB/s]
#  64%|██████▍   | 143576/224190 [00:05<00:02, 31634.62KB/s]
#  66%|██████▋   | 148632/224190 [00:05<00:02, 31684.60KB/s]
#  69%|██████▊   | 153656/224190 [00:05<00:02, 31627.80KB/s]
#  71%|███████   | 158344/224190 [00:06<00:02, 30938.90KB/s]
#  73%|███████▎  | 163320/224190 [00:06<00:01, 31011.53KB/s]
#  75%|███████▌  | 168376/224190 [00:06<00:01, 31228.20KB/s]
#  77%|███████▋  | 173448/224190 [00:06<00:01, 31369.85KB/s]
#  80%|███████▉  | 178456/224190 [00:06<00:01, 31421.68KB/s]
#  82%|████████▏ | 183576/224190 [00:06<00:01, 31584.47KB/s]
#  84%|████████▍ | 188648/224190 [00:07<00:01, 31711.34KB/s]
#  86%|████████▋ | 193736/224190 [00:07<00:00, 31689.92KB/s]
#  89%|████████▊ | 198760/224190 [00:07<00:00, 31730.59KB/s]
#  91%|█████████ | 203752/224190 [00:07<00:00, 31600.02KB/s]
#  93%|█████████▎| 208776/224190 [00:07<00:00, 31486.96KB/s]
#  95%|█████████▌| 213800/224190 [00:07<00:00, 31498.99KB/s]
#  98%|█████████▊| 218856/224190 [00:07<00:00, 31197.75KB/s]
# 100%|██████████| 224190/224190 [00:08<00:00, 27539.04KB/s]
# INFO:YOLOv3Estimator:Start training from [Epoch 0]
# [03:36:21] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# INFO:SSDEstimator:modified configs(<old> != <new>): {
# INFO:SSDEstimator:root.valid.batch_size 16 != 64
# INFO:SSDEstimator:root.dataset         voc_tiny != auto
# INFO:SSDEstimator:root.dataset_root    ~/.mxnet/datasets/ != auto
# INFO:SSDEstimator:root.train.epochs    20 != 50
# INFO:SSDEstimator:root.train.seed      233 != 46
# INFO:SSDEstimator:root.train.lr        0.001 != 0.0019578897201213
# INFO:SSDEstimator:root.train.early_stop_max_value 1.0 != inf
# INFO:SSDEstimator:root.train.early_stop_patience -1 != 20
# INFO:SSDEstimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:SSDEstimator:root.train.batch_size 16 != 64
# INFO:SSDEstimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:SSDEstimator:root.num_workers     4 != 12
# INFO:SSDEstimator:root.ssd.data_shape  300 != 512
# INFO:SSDEstimator:root.ssd.base_network vgg16_atrous != resnet50_v1
# INFO:SSDEstimator:}
# INFO:SSDEstimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_3/config.yaml
# INFO:SSDEstimator:Using transfer learning from ssd_512_resnet50_v1_coco, the other network parameters are ignored.
# INFO:SSDEstimator:modified configs(<old> != <new>): {
# INFO:SSDEstimator:root.valid.batch_size 16 != 64
# INFO:SSDEstimator:root.dataset         voc_tiny != auto
# INFO:SSDEstimator:root.dataset_root    ~/.mxnet/datasets/ != auto
# INFO:SSDEstimator:root.train.epochs    20 != 50
# INFO:SSDEstimator:root.train.seed      233 != 46
# INFO:SSDEstimator:root.train.lr        0.001 != 0.006074996073425693
# INFO:SSDEstimator:root.train.early_stop_max_value 1.0 != inf
# INFO:SSDEstimator:root.train.early_stop_patience -1 != 20
# INFO:SSDEstimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:SSDEstimator:root.train.batch_size 16 != 64
# INFO:SSDEstimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:SSDEstimator:root.num_workers     4 != 12
# INFO:SSDEstimator:root.ssd.data_shape  300 != 512
# INFO:SSDEstimator:root.ssd.base_network vgg16_atrous != resnet50_v1
# INFO:SSDEstimator:}
# INFO:SSDEstimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_4/config.yaml
# INFO:SSDEstimator:Using transfer learning from ssd_512_resnet50_v1_coco, the other network parameters are ignored.
# INFO:CenterNetEstimator:modified configs(<old> != <new>): {
# INFO:CenterNetEstimator:root.valid.num_workers 16 != 12
# INFO:CenterNetEstimator:root.center_net.base_network dla34_deconv != resnet50_v1b
# INFO:CenterNetEstimator:root.train.epochs    15 != 50
# INFO:CenterNetEstimator:root.train.lr        0.000125 != 0.0005846326121643412
# INFO:CenterNetEstimator:root.train.early_stop_patience -1 != 20
# INFO:CenterNetEstimator:root.train.early_stop_max_value 1.0 != inf
# INFO:CenterNetEstimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:CenterNetEstimator:root.train.num_workers 16 != 12
# INFO:CenterNetEstimator:root.train.batch_size 16 != 8
# INFO:CenterNetEstimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:CenterNetEstimator:}
# INFO:CenterNetEstimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_5/config.yaml
# INFO:CenterNetEstimator:Using transfer learning from center_net_resnet50_v1b_coco, ignoring some of the network configs
# Downloading /root/.mxnet/models/center_net_resnet50_v1b_coco-28c64aae.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/center_net_resnet50_v1b_coco-28c64aae.zip...
#   0%|          | 0/110292 [00:00<?, ?KB/s]
#   0%|          | 25/110292 [00:00<11:26, 160.53KB/s]
#   0%|          | 93/110292 [00:00<05:45, 318.71KB/s]
#   0%|          | 234/110292 [00:00<03:10, 578.81KB/s]
#   0%|          | 506/110292 [00:00<01:47, 1026.01KB/s]
#   1%|          | 1063/110292 [00:00<00:56, 1918.24KB/s]
#   2%|▏         | 2183/110292 [00:00<00:29, 3659.67KB/s]
#   4%|▍         | 4407/110292 [00:01<00:15, 7028.60KB/s]
#   8%|▊         | 8855/110292 [00:01<00:07, 13686.39KB/s]
#  12%|█▏        | 13223/110292 [00:01<00:05, 17961.10KB/s]
#  16%|█▋        | 17943/110292 [00:01<00:04, 21556.52KB/s]
#  21%|██        | 23049/110292 [00:01<00:03, 24767.65KB/s]
#  25%|██▌       | 27886/110292 [00:01<00:03, 26463.83KB/s]
#  29%|██▉       | 32367/110292 [00:02<00:02, 26971.99KB/s]
#  34%|███▍      | 37369/110292 [00:02<00:02, 28300.62KB/s]
#  38%|███▊      | 42413/110292 [00:02<00:02, 29319.75KB/s]
#  43%|████▎     | 47293/110292 [00:02<00:02, 29701.18KB/s]
#  47%|████▋     | 52387/110292 [00:02<00:01, 30406.92KB/s]
#  51%|█████▏    | 56592/110292 [00:02<00:01, 29172.36KB/s]
#  56%|█████▌    | 61689/110292 [00:03<00:01, 30043.18KB/s]
#  60%|██████    | 66716/110292 [00:03<00:01, 30487.60KB/s]
#  65%|██████▌   | 71737/110292 [00:03<00:01, 30803.90KB/s]
#  70%|██████▉   | 76745/110292 [00:03<00:01, 30995.12KB/s]
#  74%|███████▍  | 81850/110292 [00:03<00:00, 31318.04KB/s]
#  79%|███████▉  | 86938/110292 [00:03<00:00, 31494.37KB/s]
#  83%|████████▎ | 91962/110292 [00:03<00:00, 31500.21KB/s]
#  88%|████████▊ | 97024/110292 [00:04<00:00, 31577.49KB/s]
#  93%|█████████▎| 102048/110292 [00:04<00:00, 31561.23KB/s]
# 110293KB [00:04, 24488.89KB/s]
# INFO:SSDEstimator:modified configs(<old> != <new>): {
# INFO:SSDEstimator:root.valid.batch_size 16 != 64
# INFO:SSDEstimator:root.dataset         voc_tiny != auto
# INFO:SSDEstimator:root.dataset_root    ~/.mxnet/datasets/ != auto
# INFO:SSDEstimator:root.train.epochs    20 != 50
# INFO:SSDEstimator:root.train.seed      233 != 46
# INFO:SSDEstimator:root.train.lr        0.001 != 0.001142325415560837
# INFO:SSDEstimator:root.train.early_stop_max_value 1.0 != inf
# INFO:SSDEstimator:root.train.early_stop_patience -1 != 20
# INFO:SSDEstimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:SSDEstimator:root.train.batch_size 16 != 64
# INFO:SSDEstimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:SSDEstimator:root.num_workers     4 != 12
# INFO:SSDEstimator:root.ssd.data_shape  300 != 512
# INFO:SSDEstimator:root.ssd.base_network vgg16_atrous != resnet50_v1
# INFO:SSDEstimator:}
# INFO:SSDEstimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_6/config.yaml
# INFO:SSDEstimator:Using transfer learning from ssd_512_resnet50_v1_coco, the other network parameters are ignored.
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# INFO:YOLOv3Estimator:modified configs(<old> != <new>): {
# INFO:YOLOv3Estimator:root.dataset         voc_tiny != auto
# INFO:YOLOv3Estimator:root.dataset_root    ~/.mxnet/datasets/ != auto
# INFO:YOLOv3Estimator:root.train.lr        0.001 != 0.007098936257405899
# INFO:YOLOv3Estimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:YOLOv3Estimator:root.train.epochs    20 != 50
# INFO:YOLOv3Estimator:root.train.seed      233 != 46
# INFO:YOLOv3Estimator:root.train.early_stop_patience -1 != 20
# INFO:YOLOv3Estimator:root.train.early_stop_max_value 1.0 != inf
# INFO:YOLOv3Estimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:YOLOv3Estimator:root.num_workers     4 != 12
# INFO:YOLOv3Estimator:}
# INFO:YOLOv3Estimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_7/config.yaml
# INFO:YOLOv3Estimator:Using transfer learning from yolo3_darknet53_coco, the other network parameters are ignored.
# INFO:SSDEstimator:modified configs(<old> != <new>): {
# INFO:SSDEstimator:root.valid.batch_size 16 != 8
# INFO:SSDEstimator:root.dataset         voc_tiny != auto
# INFO:SSDEstimator:root.dataset_root    ~/.mxnet/datasets/ != auto
# INFO:SSDEstimator:root.train.epochs    20 != 50
# INFO:SSDEstimator:root.train.seed      233 != 46
# INFO:SSDEstimator:root.train.lr        0.001 != 0.00014936835544198456
# INFO:SSDEstimator:root.train.early_stop_max_value 1.0 != inf
# INFO:SSDEstimator:root.train.early_stop_patience -1 != 20
# INFO:SSDEstimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:SSDEstimator:root.train.batch_size 16 != 8
# INFO:SSDEstimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:SSDEstimator:root.num_workers     4 != 12
# INFO:SSDEstimator:root.ssd.data_shape  300 != 512
# INFO:SSDEstimator:root.ssd.base_network vgg16_atrous != resnet50_v1
# INFO:SSDEstimator:}
# INFO:SSDEstimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_8/config.yaml
# INFO:SSDEstimator:Using transfer learning from ssd_512_resnet50_v1_coco, the other network parameters are ignored.
# INFO:SSDEstimator:modified configs(<old> != <new>): {
# INFO:SSDEstimator:root.valid.batch_size 16 != 64
# INFO:SSDEstimator:root.dataset         voc_tiny != auto
# INFO:SSDEstimator:root.dataset_root    ~/.mxnet/datasets/ != auto
# INFO:SSDEstimator:root.train.epochs    20 != 50
# INFO:SSDEstimator:root.train.seed      233 != 46
# INFO:SSDEstimator:root.train.lr        0.001 != 0.008209379223637903
# INFO:SSDEstimator:root.train.early_stop_max_value 1.0 != inf
# INFO:SSDEstimator:root.train.early_stop_patience -1 != 20
# INFO:SSDEstimator:root.train.early_stop_baseline 0.0 != -inf
# INFO:SSDEstimator:root.train.batch_size 16 != 64
# INFO:SSDEstimator:root.gpus            (0, 1, 2, 3) != (0,)
# INFO:SSDEstimator:root.num_workers     4 != 12
# INFO:SSDEstimator:root.ssd.data_shape  300 != 512
# INFO:SSDEstimator:root.ssd.base_network vgg16_atrous != resnet50_v1
# INFO:SSDEstimator:}
# INFO:SSDEstimator:Saved config to /content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/968b2c6a/.trial_9/config.yaml
# INFO:SSDEstimator:Using transfer learning from ssd_512_resnet50_v1_coco, the other network parameters are ignored.
# Warning: Detected a large trial failure rate: 8/10 attempted trials failed (80.0%)! Stopping HPO early due to reaching failure threshold (80.0%).
# 	Failures may be caused by invalid configurations within the provided search space.
# Saving Training Curve in checkpoint/plot_training_curves.png
# Finished, total runtime is 9027.27 s
# { 'best_config': { 'dataset': 'auto',
#                    'dataset_root': 'auto',
#                    'estimator': <class 'gluoncv.auto.estimators.ssd.ssd.SSDEstimator'>,
#                    'gpus': [0],
#                    'horovod': False,
#                    'num_workers': 12,
#                    'resume': '',
#                    'save_interval': 1,
#                    'ssd': { 'amp': False,
#                             'base_network': 'resnet50_v1',
#                             'data_shape': 512,
#                             'filters': None,
#                             'nms_thresh': 0.45,
#                             'nms_topk': 400,
#                             'ratios': ( [1, 2, 0.5],
#                                         [1, 2, 0.5, 3, 0.3333333333333333],
#                                         [1, 2, 0.5, 3, 0.3333333333333333],
#                                         [1, 2, 0.5, 3, 0.3333333333333333],
#                                         [1, 2, 0.5],
#                                         [1, 2, 0.5]),
#                             'sizes': (30, 60, 111, 162, 213, 264, 315),
#                             'steps': (8, 16, 32, 64, 100, 300),
#                             'syncbn': False,
#                             'transfer': 'ssd_512_resnet50_v1_coco'},
#                    'train': { 'batch_size': 8,
#                               'dali': False,
#                               'early_stop_baseline': -inf,
#                               'early_stop_max_value': inf,
#                               'early_stop_min_delta': 0.001,
#                               'early_stop_patience': 20,
#                               'epochs': 50,
#                               'log_interval': 100,
#                               'lr': 0.0001,
#                               'lr_decay': 0.1,
#                               'lr_decay_epoch': (160, 200),
#                               'momentum': 0.9,
#                               'seed': 46,
#                               'start_epoch': 0,
#                               'wd': 0.0005},
#                    'valid': { 'batch_size': 8,
#                               'iou_thresh': 0.5,
#                               'metric': 'voc07',
#                               'val_interval': 1}},
#   'total_time': 9026.885636091232,
#   'train_map': 0.8600771109426166,
#   'valid_map': 0.7849530363597901}

# %%
ObjectDetector.fit_summary(detector)
# Out:
# {'train_map': 0.8600771109426166,
#  'valid_map': 0.7849530363597901,
#  'total_time': 9026.885636091232,
#  'best_config': {'ssd': {'base_network': 'resnet50_v1',
#    'data_shape': 512,
#    'filters': None,
#    'sizes': (30, 60, 111, 162, 213, 264, 315),
#    'ratios': ([1, 2, 0.5],
#     [1, 2, 0.5, 3, 0.3333333333333333],
#     [1, 2, 0.5, 3, 0.3333333333333333],
#     [1, 2, 0.5, 3, 0.3333333333333333],
#     [1, 2, 0.5],
#     [1, 2, 0.5]),
#    'steps': (8, 16, 32, 64, 100, 300),
#    'syncbn': False,
#    'amp': False,
#    'transfer': 'ssd_512_resnet50_v1_coco',
#    'nms_thresh': 0.45,
#    'nms_topk': 400},
#   'train': {'batch_size': 8,
#    'start_epoch': 0,
#    'epochs': 50,
#    'lr': 0.0001,
#    'lr_decay': 0.1,
#    'lr_decay_epoch': (160, 200),
#    'momentum': 0.9,
#    'wd': 0.0005,
#    'log_interval': 100,
#    'seed': 46,
#    'dali': False,
#    'early_stop_patience': 20,
#    'early_stop_min_delta': 0.001,
#    'early_stop_baseline': -inf,
#    'early_stop_max_value': inf},
#   'valid': {'batch_size': 8,
#    'val_interval': 1,
#    'metric': 'voc07',
#    'iou_thresh': 0.5},
#   'dataset': 'auto',
#   'dataset_root': 'auto',
#   'gpus': [0],
#   'resume': '',
#   'save_interval': 1,
#   'horovod': False,
#   'num_workers': 12,
#   'estimator': gluoncv.auto.estimators.ssd.ssd.SSDEstimator},
#  'fit_history': {'best_reward': 0.8617078085699466,
#   'best_config': {'transfer': 'ssd_512_resnet50_v1_coco',
#    'lr': 0.0001,
#    'epochs': 50,
#    'nthreads_per_trial': 128,
#    'ngpus_per_trial': 1,
#    'time_limits': 43200,
#    'dist_ip_addrs': None,
#    'scheduler': 'local',
#    'batch_size': 8,
#    'early_stop_patience': 20,
#    'early_stop_baseline': -inf,
#    'early_stop_max_value': inf,
#    'num_workers': 12,
#    'gpus': [0],
#    'seed': 46,
#    'final_fit': False},
#   'total_time': 9026.885636091232,
#   'config_history': OrderedDict([(0,
#                 {'transfer': 'ssd_512_resnet50_v1_coco',
#                  'lr': 0.0001,
#                  'epochs': 50,
#                  'nthreads_per_trial': 128,
#                  'ngpus_per_trial': 1,
#                  'time_limits': 43200,
#                  'dist_ip_addrs': None,
#                  'scheduler': 'local',
#                  'batch_size': 8,
#                  'early_stop_patience': 20,
#                  'early_stop_baseline': -inf,
#                  'early_stop_max_value': inf,
#                  'num_workers': 12,
#                  'gpus': [0],
#                  'seed': 46,
#                  'final_fit': False}),
#                (1,
#                 {'transfer': 'ssd_512_resnet50_v1_coco',
#                  'lr': 0.0015335192657991565,
#                  'epochs': 50,
#                  'nthreads_per_trial': 128,
#                  'ngpus_per_trial': 1,
#                  'time_limits': 43200,
#                  'dist_ip_addrs': None,
#                  'scheduler': 'local',
#                  'batch_size': 8,
#                  'early_stop_patience': 20,
#                  'early_stop_baseline': -inf,
#                  'early_stop_max_value': inf,
#                  'num_workers': 12,
#                  'gpus': [0],
#                  'seed': 46,
#                  'final_fit': False})]),
#   'reward_attr': 'map_reward'}}

# %% [markdown]
# # Below I'm loading the model and seeing the score against the test dataset

# %%
#detector.save(savefile1)
#! original
# savefile = '/content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/V7_reduced/V7_detector.ag'

#! modified
savefile = '/content/drive/MyDrive/Colab_Notebooks/benchmark_project/V7_reduced/V7_detector.ag'
new_detector = ObjectDetector.load(savefile)

dataset_test = ObjectDetector.Dataset.from_voc(root='V7_test/V7', splits='test')

test_map = new_detector.evaluate(dataset_test)
print("mAP on test dataset: {}".format(test_map[1][-1]))
# Out:
# /usr/local/lib/python3.9/dist-packages/mxnet/gluon/block.py:1784: UserWarning: Cannot decide type for the following arguments. Consider providing them as input:
# 	data: None
#   input_sym_arg_type = in_param.infer_type()[0]
# /usr/local/lib/python3.9/dist-packages/mxnet/gluon/block.py:1784: UserWarning: Cannot decide type for the following arguments. Consider providing them as input:
# 	data: None
#   input_sym_arg_type = in_param.infer_type()[0]
# [04:01:41] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# mAP on test dataset: 0.17138873300988006

# %%
print("mAP on test dataset: {}".format(test_map[1][-1]))
# Out:
# mAP on test dataset: 0.17138873300988006

# %%
print(test_map)
# Out:
# (['person', 'bus', 'bird', 'horse', 'dog', 'airplane', 'train', 'cat', 'boat', 'mAP'], [0.5671161517994906, 0.9592339410567998, 0.006197864250825065, 0.002727272727272727, 0.0005347593582887701, 0.00040950040950040947, 0.00010023053021950487, 0.001100594320933304, 0.00507828263559025, 0.17138873300988006])

# %%
class_names = ['person', 'bus', 'bird', 'horse', 'dog', 'airplane', 'train', 'cat', 'boat', 'mAP']
aps = [0.5671161517994906, 0.9592339410567998, 0.006197864250825065, 0.002727272727272727, 0.0005347593582887701, 0.00040950040950040947, 0.00010023053021950487, 0.001100594320933304, 0.00507828263559025, 0.17138873300988006]

# Combine the class names and APs using the zip function
results = zip(class_names, aps)

# Format the output using f-strings
print("Class\t\tAP")
print("----\t\t--")
for class_name, ap in results:
    print(f"{class_name}\t\t{ap:.4f}")
# Out:
# Class		AP
# ----		--
# person		0.5671
# bus		0.9592
# bird		0.0062
# horse		0.0027
# dog		0.0005
# airplane		0.0004
# train		0.0001
# cat		0.0011
# boat		0.0051
# mAP		0.1714

# %%
#image = '/content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/COCO_reduced/COCO_test/VOC2012/JPEGImages/005791.jpg'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# Load the image
#! original
# image_path = '/content/MyDrive/MyDrive/Colab Notebooks/benchmark_project/VOC12_reduced/VOC12_test/VOC2012/JPEGImages/002008.jpg'

#! modified
image_path = '/content/drive/MyDrive/Colab_Notebooks/benchmark_project/VOC12_reduced/VOC12_test/VOC2012/JPEGImages/002008.jpg'
image = np.array(Image.open(image_path))

# Load the prediction results
result = new_detector.predict(image)

# Create a figure and axes object
fig, ax = plt.subplots(1)

# Display the image
ax.imshow(image)

# Loop through the rows of the prediction results
for i, row in result[result['predict_score'] > 0.5].iterrows():
#for i, row in result.iterrows():
    # Get the class label, confidence score, and bounding box coordinates
    label = row['predict_class']
    score = row['predict_score']
    bbox = row['predict_rois']
    
    # Convert the normalized bounding box coordinates to pixel values
    x1 = int(bbox['xmin'] * image.shape[1])
    y1 = int(bbox['ymin'] * image.shape[0])
    x2 = int(bbox['xmax'] * image.shape[1])
    y2 = int(bbox['ymax'] * image.shape[0])
    
    # Create a rectangle patch for the bounding box
    rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=2, edgecolor='r', facecolor='none')
    
    # Add the patch to the axes object
    ax.add_patch(rect)
    
    # Add a label to the bounding box with the class label and confidence score
    ax.text(x1, y1-5, f"{label} {score:.2f}", fontsize=12, color='r')

# Show the plot
plt.show()

# %%
bulk_result = new_detector.predict(dataset_test)
# Out:
# [04:04:11] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:04:22] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:04:33] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:04:45] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:04:59] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:05:13] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:05:28] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:05:41] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:05:50] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:06:03] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:06:19] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:06:31] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:06:43] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:06:59] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:07:14] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:07:26] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:07:42] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:07:56] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:08:11] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:08:27] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:08:27] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:103: If you see this message in the middle of training, you are probably using bucketing. Consider setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable cudnn tuning.
# [04:08:42] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:08:58] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:09:13] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:09:28] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:09:42] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:09:58] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:10:12] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:10:27] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:10:40] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:10:57] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:11:10] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:11:24] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:11:38] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:11:53] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:12:08] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:12:25] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:12:37] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:12:53] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:13:08] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:13:22] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:13:38] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:13:54] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:14:07] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:14:22] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:14:37] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:14:51] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:15:06] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:15:20] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:15:33] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:15:46] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:16:02] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:16:15] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:16:30] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04:16:45] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)

# %%
bulk_result.to_csv('bulk_results.csv', index=False)

# %%
dataset_test.to_csv('dataset_test.csv', index=False)
